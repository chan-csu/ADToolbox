# %%
import os
import pathlib
from adtoolbox import core, configs, utils
import pandas as pd

WORK_DIR = pathlib.Path.cwd() / "adtoolbox_pipeline_work"
DATABASE_DIR = pathlib.Path("/Users/parsaghadermarzi/Desktop/Academics/Projects/Database/ADToolbox")
if not DATABASE_DIR.exists():
    DATABASE_DIR = WORK_DIR / "database"

db = core.Database(config=configs.Database(database_dir=DATABASE_DIR))
#db.download_qiime_classifier_db() # downloads the qiime classifier if not already installed (only needs to download once)
metadata=pd.read_table("/Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/wastewater_16s.csv",delimiter=",")
accessions=metadata["Run"].to_list()
metag_class=core.Metagenomics(configs.Metagenomics(database_dir=DATABASE_DIR))
alignment_to_gtdb={}
base=pathlib.Path(os.path.join(WORK_DIR,"sra_wastewater")) # base directory
for i in accessions:
    mg_config=configs.Metagenomics(database_dir=DATABASE_DIR, top_repseq_dir=str(base/i/"seqs"/i/"dna-sequences.fasta"),
                                   vsearch_similarity=0.90,
                                   align_to_gtdb_outputs_dir=str(base/i/"seqs"/i))
    
    mg=core.Metagenomics(mg_config)
    command=mg.align_to_gtdb(container="None")
    os.system(command)
    alignment_to_gtdb[i]=mg.get_genomes_from_gtdb_alignment(save=False)
# Out:
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 60 of 70 (85.71%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 62 of 73 (84.93%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 50 of 62 (80.65%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 75 of 83 (90.36%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 57 of 61 (93.44%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 58 of 61 (95.08%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 42 of 45 (93.33%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 97 of 102 (95.10%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 43 of 81 (53.09%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 73 of 91 (80.22%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 67 of 80 (83.75%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 87 of 89 (97.75%)
# vsearch v2.22.1_macos_aarch64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file Database/Amplicon2GenomeDBs/ssu_all_r214.fna 100%
# 880725430 nt in 708813 seqs, min 200, max 6015, avg 1243
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Searching 100%
# Matching unique query sequences: 20 of 20 (100.00%)

# %%
genome_ids=set()
for sample in alignment_to_gtdb:
    genome_ids.update(tuple(alignment_to_gtdb[sample].values()))
mg_config=configs.Metagenomics(database_dir=DATABASE_DIR, genomes_base_dir=os.path.join(WORK_DIR,"genomes"))
mg=core.Metagenomics(mg_config)
genome_address=mg.extract_genome_info(save=False)

# %%
for gid in genome_ids:
    if gid in genome_address:
        continue
    os.system(mg.download_genome(gid))
# Out:
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# receiving file list ...
# 31 files to consider
# created directory ./genomes/GCF902374565.1~NZCABKQM010000006.1
# 565/
# 565/GCF_902374565.1_MGYG-HGUT-01389/
# 565/GCF_902374565.1_MGYG-HGUT-01389/GCF_902374565.1_MGYG-HGUT-01389_assembly_report.txt
#         1888 100%    1.80MB/s    0:00:00 (xfer#1, to-check=28/31)
# 565/GCF_902374565.1_MGYG-HGUT-01389/GCF_902374565.1_MGYG-HGUT-01389_assembly_stats.txt
#         4771 100%    4.55MB/s    0:00:00 (xfer#2, to-check=27/31)
# 565/GCF_902374565.1_MGYG-HGUT-01389/GCF_902374565.1_MGYG-HGUT-01389_cds_from_genomic.fna.gz
#      1010909 100%    3.62MB/s    0:00:00 (xfer#3, to-check=26/31)
# 565/GCF_902374565.1_MGYG-HGUT-01389/GCF_902374565.1_MGYG-HGUT-01389_feature_count.txt.gz
#          265 100%    0.97kB/s    0:00:00 (xfer#4, to-check=25/31)
# 565/GCF_902374565.1_MGYG-HGUT-01389/GCF_902374565.1_MGYG-HGUT-01389_feature_table.txt.gz
#       126097 100%  441.37kB/s    0:00:00 (xfer#5, to-check=24/31)
# 565/GCF_902374565.1_MGYG-HGUT-01389/GCF_902374565.1_MGYG-HGUT-01389_genomic.fna.gz
#       970104 100%    2.47MB/s    0:00:00 (xfer#6, to-check=23/31)
# 565/GCF_902374565.1_MGYG-HGUT-01389/GCF_902374565.1_MGYG-HGUT-01389_genomic.gbff.gz
#      2363194 100%    3.78MB/s    0:00:00 (xfer#7, to-check=22/31)
# 565/GCF_902374565.1_MGYG-HGUT-01389/GCF_902374565.1_MGYG-HGUT-01389
20)
# 935/GCF_003994935.1_ASM399493v1/GCF_003994935.1_ASM399493v1_translated_cds.faa.gz
#       798984 100%    1.23MB/s    0:00:00 (xfer#13, to-check=5/20)
# 935/GCF_003994935.1_ASM399493v1/GCF_003994935.1_ASM399493v1_wgsmaster.gbff.gz
#         1679 100%    2.63kB/s    0:00:00 (xfer#14, to-check=4/20)
# 935/GCF_003994935.1_ASM399493v1/README.txt -> ../../../../../README.txt
# 935/GCF_003994935.1_ASM399493v1/annotation_hashes.txt
#          410 100%    0.64kB/s    0:00:00 (xfer#15, to-check=2/20)
# 935/GCF_003994935.1_ASM399493v1/assembly_status.txt
#           14 100%    0.02kB/s    0:00:00 (xfer#16, to-check=1/20)
# 935/GCF_003994935.1_ASM399493v1/md5checksums.txt
#         1215 100%    1.90kB/s    0:00:00 (xfer#17, to-check=0/20)
#
# sent 408 bytes  received 8865059 bytes  1970103.78 bytes/sec
# total size is 9189256  speedup is 1.04
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# receiving file list ...
# 19 files to consider
# created directory ./genomes/GCA001267515.1~CP011998.1-#6
# 515/
# 515/GCA_001267515.1_ASM126751v1/
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_assembly_report.txt
#         1388 100%    1.32MB/s    0:00:00 (xfer#1, to-check=16/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_assembly_stats.txt
#         6822 100%    6.51MB/s    0:00:00 (xfer#2, to-check=15/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_cds_from_genomic.fna.gz
#      1507242 100%    1.45MB/s    0:00:00 (xfer#3, to-check=14/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_feature_count.txt.gz
#          232 100%    0.23kB/s    0:00:00 (xfer#4, to-check=13/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_feature_table.txt.gz
#       165336 100%  136.95kB/s    0:00:01 (xfer#5, to-check=12/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_genomic.fna.gz
#      1633487 100% 1005.17kB/s    0:00:01 (xfer#6, to-check=11/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_genomic.gbff.gz
#      3804538 100%  729.22kB/s    0:00:05 (xfer#7, to-check=10/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_genomic.gff.gz
#       287457 100%  251.54kB/s    0:00:01 (xfer#8, to-check=9/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_genomic.gtf.gz
#       357349 100%    1.15MB/s    0:00:00 (xfer#9, to-check=8/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_protein.faa.gz
#       977288 100%    1.19MB/s    0:00:00 (xfer#10, to-check=7/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_protein.gpff.gz
#      2543184 100%    1.61MB/s    0:00:01 (xfer#11, to-check=6/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_rna_from_genomic.fna.gz
#         5326 100%   10.47kB/s    0:00:00 (xfer#12, to-check=5/19)
# 515/GCA_001267515.1_ASM126751v1/GCA_001267515.1_ASM126751v1_translated_cds.faa.gz
#      1097899 100%    1.22MB/s    0:00:00 (xfer#13, to-check=4/19)
# 515/GCA_001267515.1_ASM126751v1/README.txt -> ../../../../../../../all/README.txt
# 515/GCA_001267515.1_ASM126751v1/annotation_hashes.txt
#          410 100%    0.47kB/s    0:00:00 (xfer#14, to-check=2/19)
# 515/GCA_001267515.1_ASM126751v1/assembly_status.txt
#           58 100%    0.07kB/s    0:00:00 (xfer#15, to-check=1/19)
# 515/GCA_001267515.1_ASM126751v1/md5checksums.txt
#         1133 100%    1.28kB/s    0:00:00 (xfer#16, to-check=0/19)
#
# sent 386 bytes  received 11780223 bytes  1121962.76 bytes/sec
# total size is 12389184  speedup is 1.05
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# receiving file list ...
# 12 files to consider
# created directory ./genomes/GCA020717815.1~DYEK01000027.1
# 815/
# 815/GCA_020717815.1_ASM2071781v1/
# 815/GCA_020717815.1_ASM2071781v1/GCA_020717815.1_ASM2071781v1_assembly_report.txt
#         4176 100%    3.98MB/s    0:00:00 (xfer#1, to-check=9/12)
# 815/GCA_020717815.1_ASM2071781v1/GCA_020717815.1_ASM2071781v1_assembly_stats.txt
#         3553 100%    3.39MB/s    0:00:00 (xfer#2, to-check=8/12)
# 815/GCA_020717815.1_ASM2071781v1/GCA_020717815.1_ASM2071781v1_feature_count.txt.gz
#          148 100%  144.53kB/s    0:00:00 (xfer#3, to-check=7/12)
# 815/GCA_020717815.1_ASM2071781v1/GCA_020717815.1_ASM2071781v1_genomic.fna.gz
#       842665 100%    2.08MB/s    0:00:00 (xfer#4, to-check=6/12)
# 815/GCA_020717815.1_ASM2071781v1/GCA_020717815.1_ASM2071781v1_genomic.gbff.gz
#      1225168 100%    1.05MB/s    0:00:01 (xfer#5, to-check=5/12)
# 815/GCA_020717815.1_ASM2071781v1/GCA_020717815.1_ASM2071781v1_wgsmaster.gbff.gz
#         1416 100%   12.92kB/s    0:00:00 (xfer#6, to-check=4/12)
# 815/GCA_020717815.1_ASM2071781v1/README.txt -> ../../../../../README.txt
# 815/GCA_020717815.1_ASM2071781v1/annotation_hashes.txt
#          410 100%    3.74kB/s    0:00:00 (xfer#7, to-check=2/12)
# 815/GCA_020717815.1_ASM2071781v1/assembly_status.txt
#           14 100%    0.13kB/s    0:00:00 (xfer#8, to-check=1/12)
# 815/GCA_020717815.1_ASM2071781v1/md5checksums.txt
#          557 100%    5.04kB/s    0:00:00 (xfer#9, to-check=0/12)
#
# sent 232 bytes  received 2064229 bytes  825784.40 bytes/sec
# total size is 2078132  speedup is 1.01

# %%
mg.config.genomes_json_info=os.path.join(WORK_DIR,"sra_wastewater","genome_address.json")
genome_address=mg.extract_genome_info(save=False)
genome_address={k:v for k,v in genome_address.items() if k in genome_ids}
mg=core.Metagenomics(configs.Metagenomics(database_dir=DATABASE_DIR, genome_alignment_output=os.path.join(WORK_DIR,"genomes")
                                          ,genomes_base_dir=os.path.join(WORK_DIR,"genomes")))
for i in enumerate(genome_address):
        os.system(mg.align_genome_to_protein_db(genome_address[i[1]],i[1],container="None")[0])
# Out:
# Create directory tmp
# easy-search /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCA024397005.1~JAJDMT010000065.1/005/GCA_024397005.1_ASM2439700v1/GCA_024397005.1_ASM2439700v1_genomic.fna.gz ./Database/Protein_DB.fasta ./genomes/Alignment_Results_mmseq_GCA024397005.1~JAJDMT010000065.1.tsv tmp --format-mode 4
#
# MMseqs Version:                        	14-7e284
# Substitution matrix                    	aa:blosum62.out,nucl:nucleotide.out
# Add backtrace                          	false
# Alignment mode                         	3
# Alignment mode                         	0
# Allow wrapped scoring                  	false
# E-value threshold                      	0.001
# Seq. id. threshold                     	0
# Min alignment length                   	0
# Seq. id. mode                          	0
# Alternative alignments                 	0
# Coverage threshold                     	0
# Coverage mode                          	0
# Max sequence length                    	65535
# Compositional bias                     	1
# Compositional bias                     	1
# Max reject                             	2147483647
# Max accept                             	2147483647
# Include identical seq. id.             	false
# Preload mode                           	0
# Pseudo count a                         	substitution:1.100,context:1.400
# Pseudo count b                         	substitution:4.100,context:5.800
# Score bias                             	0
# Realign hits                           	false
# Realign score bias                     	-0.2
# Realign max seqs                       	2147483647
# Correlation score weight               	0
# Gap open cost                          	aa:11,nucl:5
# Gap extension cost                     	aa:1,nucl:2
# Zdrop                                  	40
# Threads                                	8
# Compressed                             	0
# Verbosity                              	3
# Seed substitution matrix               	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                            	5.7
# k-mer length                           	0
# k-score                                	seq:2147483647,prof:2147483647
# Alphabet size                          	aa:21,nucl:5
# Max results per query                  	300
# Split database                         	0
# Split mode                             	2
# Split memory limit                     	0
# Diagonal scoring                       	true
# Exact k-mer matching                   	0
# Mask residues                          	1
# Mask residues probability              	0.9
# Mask lower case residues               	0
# Minimum diagonal score                 	15
# Selected taxa
# Spaced k-mers                          	1
# Spaced k-mer pattern
# Local temporary path
# Rescore mode                           	0
# Remove hits by seq. id. and coverage   	false
# Sort results                           	0
# Mask profile                           	1
# Profile E-value threshold              	0.001
# Global sequence weighting              	false
# Allow deletions                        	false
# Filter MSA                             	1
# Use filter only at N seqs              	0
# Maximum seq. id. threshold             	0.9
# Minimum seq. id.                       	0.0
# Minimum score per column               	-20
# Minimum coverage                       	0
# Select N most diverse seqs             	1000
# Pseudo count mode                      	0
# Gap pseudo count                       	10
# Min codons in orf                      	30
# Max codons in length                   	32734
# Max orf gaps                           	2147483647
# Contig start mode                      	2
# Contig end mode                        	2
# Orf start mode                         	1
# Forward frames                         	1,2,3
# Reverse frames                         	1,2,3
# Translation table                      	1
# Translate orf                          	0
# Use all table starts                   	false
# Offset of numeric ids                  	0
# Create lookup                          	0
# Add orf stop                           	false
# Overlap between sequences              	0
# Sequence split mode                    	1
# Header split mode                      	0
# Chain overlapping alignments           	0
# Merge query                            	1
# Search type                            	0
# Search iterations                      	1
# Start sensitivity                      	4
# Search steps                           	1
# Exhaustive search mode                 	false
# Filter results during exhaustive search	0
# Strand selection                       	1
# LCA search mode                        	false
# Disk space limit                       	0
# MPI runner
# Force restart with latest tmp          	false
# Remove temporary files                 	true
# Alignment format                       	4
# Format alignment output                	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                        	false
# Overlap threshold                      	0
# Database type                          	0
# Shuffle input database                 	true
# Createdb mode                          	0
# Write lookup file                      	0
# Greedy best hits                       	false
#
# createdb /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCA024397005.1~JAJDMT010000065.1/005/GCA_024397005.1_ASM2439700v1/GCA_024397005.1_ASM2439700v1_genomic.fna.gz tmp/12287053333355711314/query --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [
# Time for merging to query_h: 0h 0m 0s 5ms
# Time for merging to query: 0h 0m 0s 4ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 46ms
# createdb ./Database/Protein_DB.fasta tmp/12287053333355711314/target --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [===
# Time for merging to target_h: 0h 0m 0s 7ms
# Time for merging to target: 0h 0m 0s 22ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 95ms
# Create directory tmp/12287053333355711314/search_tmp
# search tmp/12287053333355711314/query tmp/12287053333355711314/target tmp/12287053333355711314/result tmp/12287053333355711314/search_tmp --alignment-mode 3 -s 5.7 --remove-tmp-files 1
#
# extractorfs tmp/12287053333355711314/query tmp/12287053333355711314/search_tmp/11193449816154416247/q_orfs_aa --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 1 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 140 0s 19ms
# Time for merging to q_orfs_aa_h: 0h 0m 0s 8ms
# Time for merging to q_orfs_aa: 0h 0m 0s 9ms
# Time for processing: 0h 0m 0s 95ms
# prefilter tmp/12287053333355711314/search_tmp/11193449816154416247/q_orfs_aa tmp/12287053333355711314/target tmp/12287053333355711314/search_tmp/11193449816154416247/search/pref_0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 300 --split 0 --split-mode 2 --split-memory-limit 0 -c 0 --cov-mode 0 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3 -s 5.7
#
# Query database size: 53260 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 33885 type: Aminoacid
# Index table k-mer threshold: 112 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 33.88K 0s 435ms
# Index table: Masked residues: 24366
# Index table: fill
# [=================================================================] 33.88K 0s 375ms
# Index statistics
# Entries:          13379676
# DB size:          564 MB
# Avg k-mer size:   0.209057
# Top 10 k-mers
#     PAFDGG	925
#     NGGATM	876
#     VKQHGR	812
#     AGRKGV	740
#     IGMNGL	651
#     RSEETI	638
#     QLGDVT	636
#     EVNDGR	608
#     GGPNDV	602
#     NFDGAT	592
# Time for index table init: 0h 0m 1s 112ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 112
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 53260
# Target db start 1 to 33885
# [=================================================================] 53.26K 4s 10ms
#
# 171.804875 k-mers per position
# 2375 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 15 sequences passed prefiltering per query sequence
# 2 median result list length
# 16977 sequences with 0 size result lists
# Time for merging to pref_0: 0h 0m 0s 11ms
# Time for processing: 0h 0m 5s 641ms
# align tmp/12287053333355711314/search_tmp/11193449816154416247/q_orfs_aa tmp/12287053333355711314/target tmp/12287053333355711314/search_tmp/11193449816154416247/search/pref_0 tmp/12287053333355711314/search_tmp/11193449816154416247/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 53260 type: Aminoacid
# Target database size: 33885 type: Aminoacid
# Calculation of alignments
# [=================================================================] 53.26K 8s 694ms
# Time for merging to aln: 0h 0m 0s 9ms
# 838288 alignments calculated
# 29210 sequence pairs passed the thresholds (0.034845 of overall calculated)
# 0.548442 hits per query sequence
# Time for processing: 0h 0m 8s 715ms
# rmdb tmp/12287053333355711314/search_tmp/11193449816154416247/search/pref_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/search_tmp/11193449816154416247/search/aln_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/search_tmp/11193449816154416247/search/input_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/search_tmp/11193449816154416247/search/aln_merge -v 3
#
# Time for processing: 0h 0m 0s 0ms
# offsetalignment tmp/12287053333355711314/query tmp/12287053333355711314/search_tmp/11193449816154416247/q_orfs_aa tmp/12287053333355711314/target tmp/12287053333355711314/target tmp/12287053333355711314/search_tmp/11193449816154416247/aln tmp/12287053333355711314/result --chain-alignments 0 --merge-query 1 --search-type 0 --threads 8 --compressed 0 --db-load-mode 0 -v 3
#
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 3ms
# Writing results to: tmp/12287053333355711314/result
# [=================================================================] 140 0s 11ms
#
# Time for merging to result: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 25ms
# rmdb tmp/12287053333355711314/search_tmp/11193449816154416247/q_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/search_tmp/11193449816154416247/t_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/search_tmp/11193449816154416247/aln -v 3
#
# Time for processing: 0h 0m 0s 0ms
# convertalis tmp/12287053333355711314/query tmp/12287053333355711314/target tmp/12287053333355711314/result ./genomes/Alignment_Results_mmseq_GCA024397005.1~JAJDMT010000065.1.tsv --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --format-mode 4 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --db-output 0 --db-load-mode 0 --search-type 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 140 0s 16ms
# Time for merging to Alignment_Results_mmseq_GCA024397005.1~JAJDMT010000065.1.tsv: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 23ms
# rmdb tmp/12287053333355711314/result -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/target -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/target_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/query -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12287053333355711314/query_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# easy-search /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCA016715165.1~JADKBD010000001.1/165/GCA_016715165.1_ASM1671516v1/GCA_016715165.1_ASM1671516v1_genomic.fna.gz ./Database/Protein_DB.fasta ./genomes/Alignment_Results_mmseq_GCA016715165.1~JADKBD010000001.1.tsv tmp --format-mode 4
#
# MMseqs Version:                        	14-7e284
# Substitution matrix                    	aa:blosum62.out,nucl:nucleotide.out
# Add backtrace                          	false
# Alignment mode                         	3
# Alignment mode                         	0
# Allow wrapped scoring                  	false
# E-value threshold                      	0.001
# Seq. id. threshold                     	0
# Min alignment length                   	0
# Seq. id. mode                          	0
# Alternative alignments                 	0
# Coverage threshold                     	0
# Coverage mode                          	0
# Max sequence length                    	65535
# Compositional bias                     	1
# Compositional bias                     	1
# Max reject                             	2147483647
# Max accept                             	2147483647
# Include identical seq. id.             	false
# Preload mode                           	0
# Pseudo count a                         	substitution:1.100,context:1.400
# Pseudo count b                         	substitution:4.100,context:5.800
# Score bias                             	0
# Realign hits                           	false
# Realign score bias                     	-0.2
# Realign max seqs                       	2147483647
# Correlation score weight               	0
# Gap open cost                          	aa:11,nucl:5
# Gap extension cost                     	aa:1,nucl:2
# Zdrop                                  	40
# Threads                                	8
# Compressed                             	0
# Verbosity                              	3
# Seed substitution matrix               	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                            	5.7
# k-mer length                           	0
# k-score                                	seq:2147483647,prof:2147483647
# Alphabet size                          	aa:21,nucl:5
# Max results per query                  	300
# Split database                         	0
# Split mode                             	2
# Split memory limit                     	0
# Diagonal scoring                       	true
# Exact k-mer matching                   	0
# Mask residues                          	1
# Mask residues probability              	0.9
# Mask lower case residues               	0
# Minimum diagonal score                 	15
# Selected taxa
# Spaced k-mers                          	1
# Spaced k-mer pattern
# Local temporary path
# Rescore mode                           	0
# Remove hits by seq. id. and coverage   	false
# Sort results                           	0
# Mask profile                           	1
# Profile E-value threshold              	0.001
# Global sequence weighting              	false
# Allow deletions                        	false
# Filter MSA                             	1
# Use filter only at N seqs              	0
# Maximum seq. id. threshold             	0.9
# Minimum seq. id.                       	0.0
# Minimum score per column               	-20
# Minimum coverage                       	0
# Select N most diverse seqs             	1000
# Pseudo count mode                      	0
# Gap pseudo count                       	10
# Min codons in orf                      	30
# Max codons in length                   	32734
# Max orf gaps                           	2147483647
# Contig start mode                      	2
# Contig end mode                        	2
# Orf start mode                         	1
# Forward frames                         	1,2,3
# Reverse frames                         	1,2,3
# Translation table                      	1
# Translate orf                          	0
# Use all table starts                   	false
# Offset of numeric ids                  	0
# Create lookup                          	0
# Add orf stop                           	false
# Overlap between sequences              	0
# Sequence split mode                    	1
# Header split mode                      	0
# Chain overlapping alignments           	0
# Merge query                            	1
# Search type                            	0
# Search iterations                      	1
# Start sensitivity                      	4
# Search steps                           	1
# Exhaustive search mode                 	false
# Filter results during exhaustive search	0
# Strand selection                       	1
# LCA search mode                        	false
# Disk space limit                       	0
# MPI runner
# Force restart with latest tmp          	false
# Remove temporary files                 	true
# Alignment format                       	4
# Format alignment output                	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                        	false
# Overlap threshold                      	0
# Database type                          	0
# Shuffle input database                 	true
# Createdb mode                          	0
# Write lookup file                      	0
# Greedy best hits                       	false
#
# createdb /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCA016715165.1~JADKBD010000001.1/165/GCA_016715165.1_ASM1671516v1/GCA_016715165.1_ASM1671516v1_genomic.fna.gz tmp/6402734860072642204/query --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [
# Time for merging to query_h: 0h 0m 0s 4ms
# Time for merging to query: 0h 0m 0s 6ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 53ms
# createdb ./Database/Protein_DB.fasta tmp/6402734860072642204/target --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [===
# Time for merging to target_h: 0h 0m 0s 7ms
# Time for merging to target: 0h 0m 0s 13ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 77ms
# Create directory tmp/6402734860072642204/search_tmp
# search tmp/6402734860072642204/query tmp/6402734860072642204/target tmp/6402734860072642204/result tmp/6402734860072642204/search_tmp --alignment-mode 3 -s 5.7 --remove-tmp-files 1
#
# extractorfs tmp/6402734860072642204/query tmp/6402734860072642204/search_tmp/16747940706502619858/q_orfs_aa --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 1 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 30 0s 33ms
# Time for merging to q_orfs_aa_h: 0h 0m 0s 14ms
# Time for merging to q_orfs_aa: 0h 0m 0s 18ms
# Time for processing: 0h 0m 0s 155ms
# prefilter tmp/6402734860072642204/search_tmp/16747940706502619858/q_orfs_aa tmp/6402734860072642204/target tmp/6402734860072642204/search_tmp/16747940706502619858/search/pref_0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 300 --split 0 --split-mode 2 --split-memory-limit 0 -c 0 --cov-mode 0 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3 -s 5.7
#
# Query database size: 97578 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 33885 type: Aminoacid
# Index table k-mer threshold: 112 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 33.88K 0s 445ms
# Index table: Masked residues: 24366
# Index table: fill
# [=================================================================] 33.88K 0s 349ms
# Index statistics
# Entries:          13379676
# DB size:          564 MB
# Avg k-mer size:   0.209057
# Top 10 k-mers
#     PAFDGG	925
#     NGGATM	876
#     VKQHGR	812
#     AGRKGV	740
#     IGMNGL	651
#     RSEETI	638
#     QLGDVT	636
#     EVNDGR	608
#     GGPNDV	602
#     NFDGAT	592
# Time for index table init: 0h 0m 1s 17ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 112
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 97578
# Target db start 1 to 33885
# [=================================================================] 97.58K 11s 640ms
#
# 346.166547 k-mers per position
# 3357 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 23 sequences passed prefiltering per query sequence
# 9 median result list length
# 9509 sequences with 0 size result lists
# Time for merging to pref_0: 0h 0m 0s 26ms
# Time for processing: 0h 0m 13s 155ms
# align tmp/6402734860072642204/search_tmp/16747940706502619858/q_orfs_aa tmp/6402734860072642204/target tmp/6402734860072642204/search_tmp/16747940706502619858/search/pref_0 tmp/6402734860072642204/search_tmp/16747940706502619858/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 97578 type: Aminoacid
# Target database size: 33885 type: Aminoacid
# Calculation of alignments
# [=================================================================] 97.58K 17s 697ms
# Time for merging to aln: 0h 0m 0s 18ms
# 2339537 alignments calculated
# 26179 sequence pairs passed the thresholds (0.011190 of overall calculated)
# 0.268288 hits per query sequence
# Time for processing: 0h 0m 17s 737ms
# rmdb tmp/6402734860072642204/search_tmp/16747940706502619858/search/pref_0 -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb tmp/6402734860072642204/search_tmp/16747940706502619858/search/aln_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/6402734860072642204/search_tmp/16747940706502619858/search/input_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/6402734860072642204/search_tmp/16747940706502619858/search/aln_merge -v 3
#
# Time for processing: 0h 0m 0s 0ms
# offsetalignment tmp/6402734860072642204/query tmp/6402734860072642204/search_tmp/16747940706502619858/q_orfs_aa tmp/6402734860072642204/target tmp/6402734860072642204/target tmp/6402734860072642204/search_tmp/16747940706502619858/aln tmp/6402734860072642204/result --chain-alignments 0 --merge-query 1 --search-type 0 --threads 8 --compressed 0 --db-load-mode 0 -v 3
#
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 5ms
# Writing results to: tmp/6402734860072642204/result
# [=================================================================] 30 0s 13ms
#
# Time for merging to result: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 37ms
# rmdb tmp/6402734860072642204/search_tmp/16747940706502619858/q_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/6402734860072642204/search_tmp/16747940706502619858/t_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/6402734860072642204/search_tmp/16747940706502619858/aln -v 3
#
# Time for processing: 0h 0m 0s 0ms
# convertalis tmp/6402734860072642204/query tmp/6402734860072642204/target tmp/6402734860072642204/result ./genomes/Alignment_Results_mmseq_GCA016715165.1~JADKBD010000001.1.tsv --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --format-mode 4 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --db-output 0 --db-load-mode 0 --search-type 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 30 0s 14ms
# Time for merging to Alignment_Results_mmseq_GCA016715165.1~JADKBD010000001.1.tsv: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 22ms
# rmdb tmp/6402734860072642204/result -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/6402734860072642204/target -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/6402734860072642204/target_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/6402734860072642204/query -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/6402734860072642204/query_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# easy-search /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCF020804205.1~NZWJBJ01000030.1/205/GCF_020804205.1_ASM2080420v1/GCF_020804205.1_ASM2080420v1_genomic.fna.gz ./Database/Protein_DB.fasta ./genomes/Alignment_Results_mmseq_GCF020804205.1~NZWJBJ01000030.1.tsv tmp --format-mode 4
#
# MMseqs Version:                        	14-7e284
# Substitution matrix                    	aa:blosum62.out,nucl:nucleotide.out
# Add backtrace                          	false
# Alignment mode                         	3
# Alignment mode                         	0
# Allow wrapped scoring                  	false
# E-value threshold                      	0.001
# Seq. id. threshold                     	0
# Min alignment length                   	0
# Seq. id. mode                          	0
# Alternative alignments                 	0
# Coverage threshold                     	0
# Coverage mode                          	0
# Max sequence length                    	65535
# Compositional bias                     	1
# Compositional bias                     	1
# Max reject                             	2147483647
# Max accept                             	2147483647
# Include identical seq. id.             	false
# Preload mode                           	0
# Pseudo count a                         	substitution:1.100,context:1.400
# Pseudo count b                         	substitution:4.100,context:5.800
# Score bias                             	0
# Realign hits                           	false
# Realign score bias                     	-0.2
# Realign max seqs                       	2147483647
# Correlation score weight               	0
# Gap open cost                          	aa:11,nucl:5
# Gap extension cost                     	aa:1,nucl:2
# Zdrop                                  	40
# Threads                                	8
# Compressed                             	0
# Verbosity                              	3
# Seed substitution matrix               	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                            	5.7
# k-mer length                           	0
# k-score                                	seq:2147483647,prof:2147483647
# Alphabet size                          	aa:21,nucl:5
# Max results per query                  	300
# Split database                         	0
# Split mode                             	2
# Split memory limit                     	0
# Diagonal scoring                       	true
# Exact k-mer matching                   	0
# Mask residues                          	1
# Mask residues probability              	0.9
# Mask lower case residues               	0
# Minimum diagonal score                 	15
# Selected taxa
# Spaced k-mers                          	1
# Spaced k-mer pattern
# Local temporary path
# Rescore mode                           	0
# Remove hits by seq. id. and coverage   	false
# Sort results                           	0
# Mask profile                           	1
# Profile E-value threshold              	0.001
# Global sequence weighting              	false
# Allow deletions                        	false
# Filter MSA                             	1
# Use filter only at N seqs              	0
# Maximum seq. id. threshold             	0.9
# Minimum seq. id.                       	0.0
# Minimum score per column               	-20
# Minimum coverage                       	0
# Select N most diverse seqs             	1000
# Pseudo count mode                      	0
# Gap pseudo count                       	10
# Min codons in orf                      	30
# Max codons in length                   	32734
# Max orf gaps                           	2147483647
# Contig start mode                      	2
# Contig end mode                        	2
# Orf start mode                         	1
# Forward frames                         	1,2,3
# Reverse frames                         	1,2,3
# Translation table                      	1
# Translate orf                          	0
# Use all table starts                   	false
# Offset of numeric ids                  	0
# Create lookup                          	0
# Add orf stop                           	false
# Overlap between sequences              	0
# Sequence split mode                    	1
# Header split mode                      	0
# Chain overlapping alignments           	0
# Merge query                            	1
# Search type                            	0
# Search iterations                      	1
# Start sensitivity                      	4
# Search steps                           	1
# Exhaustive search mode                 	false
# Filter results during exhaustive search	0
# Strand selection                       	1
# LCA search mode                        	false
# Disk space limit                       	0
# MPI runner
# Force restart with latest tmp          	false
# Remove temporary files                 	true
# Alignment format                       	4
# Format alignment output                	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                        	false
# Overlap threshold                      	0
# Database type                          	0
# Shuffle input database                 	true
# Createdb mode                          	0
# Write lookup file                      	0
# Greedy best hits                       	false
#
# createdb /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCF020804205.1~NZWJBJ01000030.1/205/GCF_020804205.1_ASM2080420v1/GCF_020804205.1_ASM2080420v1_genomic.fna.gz tmp/18399010629748562836/query --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [
# Time for merging to query_h: 0h 0m 0s 4ms
# Time for merging to query: 0h 0m 0s 5ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 43ms
# createdb ./Database/Protein_DB.fasta tmp/18399010629748562836/target --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [===
# Time for merging to target_h: 0h 0m 0s 7ms
# Time for merging to target: 0h 0m 0s 11ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 77ms
# Create directory tmp/18399010629748562836/search_tmp
# search tmp/18399010629748562836/query tmp/18399010629748562836/target tmp/18399010629748562836/result tmp/18399010629748562836/search_tmp --alignment-mode 3 -s 5.7 --remove-tmp-files 1
#
# extractorfs tmp/18399010629748562836/query tmp/18399010629748562836/search_tmp/5902933813798550433/q_orfs_aa --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 1 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 51 0s 29ms
# Time for merging to q_orfs_aa_h: 0h 0m 0s 13ms
# Time for merging to q_orfs_aa: 0h 0m 0s 14ms
# Time for processing: 0h 0m 0s 86ms
# prefilter tmp/18399010629748562836/search_tmp/5902933813798550433/q_orfs_aa tmp/18399010629748562836/target tmp/18399010629748562836/search_tmp/5902933813798550433/search/pref_0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 300 --split 0 --split-mode 2 --split-memory-limit 0 -c 0 --cov-mode 0 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3 -s 5.7
#
# Query database size: 77016 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 33885 type: Aminoacid
# Index table k-mer threshold: 112 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 33.88K 0s 402ms
# Index table: Masked residues: 24366
# Index table: fill
# [=================================================================] 33.88K 0s 332ms
# Index statistics
# Entries:          13379676
# DB size:          564 MB
# Avg k-mer size:   0.209057
# Top 10 k-mers
#     PAFDGG	925
#     NGGATM	876
#     VKQHGR	812
#     AGRKGV	740
#     IGMNGL	651
#     RSEETI	638
#     QLGDVT	636
#     EVNDGR	608
#     GGPNDV	602
#     NFDGAT	592
# Time for index table init: 0h 0m 0s 969ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 112
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 77016
# Target db start 1 to 33885
# [=================================================================] 77.02K 6s 732ms
#
# 280.044768 k-mers per position
# 2817 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 20 sequences passed prefiltering per query sequence
# 7 median result list length
# 9744 sequences with 0 size result lists
# Time for merging to pref_0: 0h 0m 0s 21ms
# Time for processing: 0h 0m 8s 191ms
# align tmp/18399010629748562836/search_tmp/5902933813798550433/q_orfs_aa tmp/18399010629748562836/target tmp/18399010629748562836/search_tmp/5902933813798550433/search/pref_0 tmp/18399010629748562836/search_tmp/5902933813798550433/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 77016 type: Aminoacid
# Target database size: 33885 type: Aminoacid
# Calculation of alignments
# [=================================================================] 77.02K 10s 915ms
# Time for merging to aln: 0h 0m 0s 13ms
# 1557097 alignments calculated
# 16395 sequence pairs passed the thresholds (0.010529 of overall calculated)
# 0.212878 hits per query sequence
# Time for processing: 0h 0m 10s 951ms
# rmdb tmp/18399010629748562836/search_tmp/5902933813798550433/search/pref_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/search_tmp/5902933813798550433/search/aln_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/search_tmp/5902933813798550433/search/input_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/search_tmp/5902933813798550433/search/aln_merge -v 3
#
# Time for processing: 0h 0m 0s 0ms
# offsetalignment tmp/18399010629748562836/query tmp/18399010629748562836/search_tmp/5902933813798550433/q_orfs_aa tmp/18399010629748562836/target tmp/18399010629748562836/target tmp/18399010629748562836/search_tmp/5902933813798550433/aln tmp/18399010629748562836/result --chain-alignments 0 --merge-query 1 --search-type 0 --threads 8 --compressed 0 --db-load-mode 0 -v 3
#
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 3ms
# Writing results to: tmp/18399010629748562836/result
# [=================================================================] 51 0s 5ms
#
# Time for merging to result: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 22ms
# rmdb tmp/18399010629748562836/search_tmp/5902933813798550433/q_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/search_tmp/5902933813798550433/t_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/search_tmp/5902933813798550433/aln -v 3
#
# Time for processing: 0h 0m 0s 0ms
# convertalis tmp/18399010629748562836/query tmp/18399010629748562836/target tmp/18399010629748562836/result ./genomes/Alignment_Results_mmseq_GCF020804205.1~NZWJBJ01000030.1.tsv --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --format-mode 4 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --db-output 0 --db-load-mode 0 --search-type 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 51 0s 7ms
# Time for merging to Alignment_Results_mmseq_GCF020804205.1~NZWJBJ01000030.1.tsv: 0h 0m 0s 1ms
# Time for processing: 0h 0m 0s 17ms
# rmdb tmp/18399010629748562836/result -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/target -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/target_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/query -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/18399010629748562836/query_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# easy-search /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCF001262605.1~NZLGTC01000001.1/605/GCF_001262605.1_ASM126260v1/GCF_001262605.1_ASM126260v1_genomic.fna.gz ./Database/Protein_DB.fasta ./genomes/Alignment_Results_mmseq_GCF001262605.1~NZLGTC01000001.1.tsv tmp --format-mode 4
#
# MMseqs Version:                        	14-7e284
# Substitution matrix                    	aa:blosum62.out,nucl:nucleotide.out
# Add backtrace                          	false
# Alignment mode                         	3
# Alignment mode                         	0
# Allow wrapped scoring                  	false
# E-value threshold                      	0.001
# Seq. id. threshold                     	0
# Min alignment length                   	0
# Seq. id. mode                          	0
# Alternative alignments                 	0
# Coverage threshold                     	0
# Coverage mode                          	0
# Max sequence length                    	65535
# Compositional bias                     	1
# Compositional bias                     	1
# Max reject                             	2147483647
# Max accept                             	2147483647
# Include identical seq. id.             	false
# Preload mode                           	0
# Pseudo count a                         	substitution:1.100,context:1.400
# Pseudo count b                         	substitution:4.100,context:5.800
# Score bias                             	0
# Realign hits                           	false
# Realign score bias                     	-0.2
# Realign max seqs                       	2147483647
# Correlation score weight               	0
# Gap open cost                          	aa:11,nucl:5
# Gap extension cost                     	aa:1,nucl:2
# Zdrop                                  	40
# Threads                                	8
# Compressed                             	0
# Verbosity                              	3
# Seed substitution matrix               	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                            	5.7
# k-mer length                           	0
# k-score                                	seq:2147483647,prof:2147483647
# Alphabet size                          	aa:21,nucl:5
# Max results per query                  	300
# Split database                         	0
# Split mode                             	2
# Split memory limit                     	0
# Diagonal scoring                       	true
# Exact k-mer matching                   	0
# Mask residues                          	1
# Mask residues probability              	0.9
# Mask lower case residues               	0
# Minimum diagonal score                 	15
# Selected taxa
# Spaced k-mers                          	1
# Spaced k-mer pattern
# Local temporary path
# Rescore mode                           	0
# Remove hits by seq. id. and coverage   	false
# Sort results                           	0
# Mask profile                           	1
# Profile E-value threshold              	0.001
# Global sequence weighting              	false
# Allow deletions                        	false
# Filter MSA                             	1
# Use filter only at N seqs              	0
# Maximum seq. id. threshold             	0.9
# Minimum seq. id.                       	0.0
# Minimum score per column               	-20
# Minimum coverage                       	0
# Select N most diverse seqs             	1000
# Pseudo count mode                      	0
# Gap pseudo count                       	10
# Min codons in orf                      	30
# Max codons in length                   	32734
# Max orf gaps                           	2147483647
# Contig start mode                      	2
# Contig end mode                        	2
# Orf start mode                         	1
# Forward frames                         	1,2,3
# Reverse frames                         	1,2,3
# Translation table                      	1
# Translate orf                          	0
# Use all table starts                   	false
# Offset of numeric ids                  	0
# Create lookup                          	0
# Add orf stop                           	false
# Overlap between sequences              	0
# Sequence split mode                    	1
# Header split mode                      	0
# Chain overlapping alignments           	0
# Merge query                            	1
# Search type                            	0
# Search iterations                      	1
# Start sensitivity                      	4
# Search steps                           	1
# Exhaustive search mode                 	false
# Filter results during exhaustive search	0
# Strand selection                       	1
# LCA search mode                        	false
# Disk space limit                       	0
# MPI runner
# Force restart with latest tmp          	false
# Remove temporary files                 	true
# Alignment format                       	4
# Format alignment output                	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                        	false
# Overlap threshold                      	0
# Database type                          	0
# Shuffle input database                 	true
# Createdb mode                          	0
# Write lookup file                      	0
# Greedy best hits                       	false
#
# createdb /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCF001262605.1~NZLGTC01000001.1/605/GCF_001262605.1_ASM126260v1/GCF_001262605.1_ASM126260v1_genomic.fna.gz tmp/17064273456985717454/query --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [
# Time for merging to query_h: 0h 0m 0s 2ms
# Time for merging to query: 0h 0m 0s 5ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 52ms
# createdb ./Database/Protein_DB.fasta tmp/17064273456985717454/target --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [===
# Time for merging to target_h: 0h 0m 0s 7ms
# Time for merging to target: 0h 0m 0s 15ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 79ms
# Create directory tmp/17064273456985717454/search_tmp
# search tmp/17064273456985717454/query tmp/17064273456985717454/target tmp/17064273456985717454/result tmp/17064273456985717454/search_tmp --alignment-mode 3 -s 5.7 --remove-tmp-files 1
#
# extractorfs tmp/17064273456985717454/query tmp/17064273456985717454/search_tmp/17622673808852703045/q_orfs_aa --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 1 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 1 0s 1ms
# Time for merging to q_orfs_aa_h: 0h 0m 0s 7ms
# Time for merging to q_orfs_aa: 0h 0m 0s 11ms
# Time for processing: 0h 0m 0s 225ms
# prefilter tmp/17064273456985717454/search_tmp/17622673808852703045/q_orfs_aa tmp/17064273456985717454/target tmp/17064273456985717454/search_tmp/17622673808852703045/search/pref_0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 300 --split 0 --split-mode 2 --split-memory-limit 0 -c 0 --cov-mode 0 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3 -s 5.7
#
# Query database size: 99057 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 33885 type: Aminoacid
# Index table k-mer threshold: 112 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 33.88K 0s 420ms
# Index table: Masked residues: 24366
# Index table: fill
# [=================================================================] 33.88K 0s 328ms
# Index statistics
# Entries:          13379676
# DB size:          564 MB
# Avg k-mer size:   0.209057
# Top 10 k-mers
#     PAFDGG	925
#     NGGATM	876
#     VKQHGR	812
#     AGRKGV	740
#     IGMNGL	651
#     RSEETI	638
#     QLGDVT	636
#     EVNDGR	608
#     GGPNDV	602
#     NFDGAT	592
# Time for index table init: 0h 0m 0s 978ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 112
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 99057
# Target db start 1 to 33885
# [=================================================================] 99.06K 9s 61ms
#
# 268.984903 k-mers per position
# 2769 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 18 sequences passed prefiltering per query sequence
# 5 median result list length
# 15563 sequences with 0 size result lists
# Time for merging to pref_0: 0h 0m 0s 20ms
# Time for processing: 0h 0m 10s 487ms
# ...
#
# Compute score, coverage and sequence identity
# Query database size: 38533 type: Aminoacid
# Target database size: 33885 type: Aminoacid
# Calculation of alignments
# [=================================================================] 38.53K 10s 175ms
# Time for merging to aln: 0h 0m 0s 8ms
# 686949 alignments calculated
# 25385 sequence pairs passed the thresholds (0.036953 of overall calculated)
# 0.658786 hits per query sequence
# Time for processing: 0h 0m 10s 195ms
# rmdb tmp/772661857740591568/search_tmp/10342214569840555992/search/pref_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/search_tmp/10342214569840555992/search/aln_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/search_tmp/10342214569840555992/search/input_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/search_tmp/10342214569840555992/search/aln_merge -v 3
#
# Time for processing: 0h 0m 0s 0ms
# offsetalignment tmp/772661857740591568/query tmp/772661857740591568/search_tmp/10342214569840555992/q_orfs_aa tmp/772661857740591568/target tmp/772661857740591568/target tmp/772661857740591568/search_tmp/10342214569840555992/aln tmp/772661857740591568/result --chain-alignments 0 --merge-query 1 --search-type 0 --threads 8 --compressed 0 --db-load-mode 0 -v 3
#
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 5ms
# Writing results to: tmp/772661857740591568/result
# [=================================================================] 1 0s 0ms
#
# Time for merging to result: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 40ms
# rmdb tmp/772661857740591568/search_tmp/10342214569840555992/q_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/search_tmp/10342214569840555992/t_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/search_tmp/10342214569840555992/aln -v 3
#
# Time for processing: 0h 0m 0s 0ms
# convertalis tmp/772661857740591568/query tmp/772661857740591568/target tmp/772661857740591568/result ./genomes/Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#4.tsv --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --format-mode 4 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --db-output 0 --db-load-mode 0 --search-type 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 1 0s 0ms
# Time for merging to Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#4.tsv: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 36ms
# rmdb tmp/772661857740591568/result -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/target -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/target_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/query -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/772661857740591568/query_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# easy-search /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCF006016075.1~NZCP040093.1-#3/075/GCF_006016075.1_ASM601607v1/GCF_006016075.1_ASM601607v1_genomic.fna.gz ./Database/Protein_DB.fasta ./genomes/Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#3.tsv tmp --format-mode 4
#
# MMseqs Version:                        	14-7e284
# Substitution matrix                    	aa:blosum62.out,nucl:nucleotide.out
# Add backtrace                          	false
# Alignment mode                         	3
# Alignment mode                         	0
# Allow wrapped scoring                  	false
# E-value threshold                      	0.001
# Seq. id. threshold                     	0
# Min alignment length                   	0
# Seq. id. mode                          	0
# Alternative alignments                 	0
# Coverage threshold                     	0
# Coverage mode                          	0
# Max sequence length                    	65535
# Compositional bias                     	1
# Compositional bias                     	1
# Max reject                             	2147483647
# Max accept                             	2147483647
# Include identical seq. id.             	false
# Preload mode                           	0
# Pseudo count a                         	substitution:1.100,context:1.400
# Pseudo count b                         	substitution:4.100,context:5.800
# Score bias                             	0
# Realign hits                           	false
# Realign score bias                     	-0.2
# Realign max seqs                       	2147483647
# Correlation score weight               	0
# Gap open cost                          	aa:11,nucl:5
# Gap extension cost                     	aa:1,nucl:2
# Zdrop                                  	40
# Threads                                	8
# Compressed                             	0
# Verbosity                              	3
# Seed substitution matrix               	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                            	5.7
# k-mer length                           	0
# k-score                                	seq:2147483647,prof:2147483647
# Alphabet size                          	aa:21,nucl:5
# Max results per query                  	300
# Split database                         	0
# Split mode                             	2
# Split memory limit                     	0
# Diagonal scoring                       	true
# Exact k-mer matching                   	0
# Mask residues                          	1
# Mask residues probability              	0.9
# Mask lower case residues               	0
# Minimum diagonal score                 	15
# Selected taxa
# Spaced k-mers                          	1
# Spaced k-mer pattern
# Local temporary path
# Rescore mode                           	0
# Remove hits by seq. id. and coverage   	false
# Sort results                           	0
# Mask profile                           	1
# Profile E-value threshold              	0.001
# Global sequence weighting              	false
# Allow deletions                        	false
# Filter MSA                             	1
# Use filter only at N seqs              	0
# Maximum seq. id. threshold             	0.9
# Minimum seq. id.                       	0.0
# Minimum score per column               	-20
# Minimum coverage                       	0
# Select N most diverse seqs             	1000
# Pseudo count mode                      	0
# Gap pseudo count                       	10
# Min codons in orf                      	30
# Max codons in length                   	32734
# Max orf gaps                           	2147483647
# Contig start mode                      	2
# Contig end mode                        	2
# Orf start mode                         	1
# Forward frames                         	1,2,3
# Reverse frames                         	1,2,3
# Translation table                      	1
# Translate orf                          	0
# Use all table starts                   	false
# Offset of numeric ids                  	0
# Create lookup                          	0
# Add orf stop                           	false
# Overlap between sequences              	0
# Sequence split mode                    	1
# Header split mode                      	0
# Chain overlapping alignments           	0
# Merge query                            	1
# Search type                            	0
# Search iterations                      	1
# Start sensitivity                      	4
# Search steps                           	1
# Exhaustive search mode                 	false
# Filter results during exhaustive search	0
# Strand selection                       	1
# LCA search mode                        	false
# Disk space limit                       	0
# MPI runner
# Force restart with latest tmp          	false
# Remove temporary files                 	true
# Alignment format                       	4
# Format alignment output                	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                        	false
# Overlap threshold                      	0
# Database type                          	0
# Shuffle input database                 	true
# Createdb mode                          	0
# Write lookup file                      	0
# Greedy best hits                       	false
#
# createdb /Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/genomes/GCF006016075.1~NZCP040093.1-#3/075/GCF_006016075.1_ASM601607v1/GCF_006016075.1_ASM601607v1_genomic.fna.gz tmp/15449720235936051922/query --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [
# Time for merging to query_h: 0h 0m 0s 2ms
# Time for merging to query: 0h 0m 0s 4ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 39ms
# createdb ./Database/Protein_DB.fasta tmp/15449720235936051922/target --dbtype 0 --shuffle 1 --createdb-mode 0 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Converting sequences
# [===
# Time for merging to target_h: 0h 0m 0s 9ms
# Time for merging to target: 0h 0m 0s 19ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 96ms
# Create directory tmp/15449720235936051922/search_tmp
# search tmp/15449720235936051922/query tmp/15449720235936051922/target tmp/15449720235936051922/result tmp/15449720235936051922/search_tmp --alignment-mode 3 -s 5.7 --remove-tmp-files 1
#
# extractorfs tmp/15449720235936051922/query tmp/15449720235936051922/search_tmp/1698286959523647864/q_orfs_aa --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 1 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 1 0s 1ms
# Time for merging to q_orfs_aa_h: 0h 0m 0s 5ms
# Time for merging to q_orfs_aa: 0h 0m 0s 5ms
# Time for processing: 0h 0m 0s 147ms
# prefilter tmp/15449720235936051922/search_tmp/1698286959523647864/q_orfs_aa tmp/15449720235936051922/target tmp/15449720235936051922/search_tmp/1698286959523647864/search/pref_0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 300 --split 0 --split-mode 2 --split-memory-limit 0 -c 0 --cov-mode 0 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3 -s 5.7
#
# Query database size: 38533 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 33885 type: Aminoacid
# Index table k-mer threshold: 112 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 33.88K 1s 88ms
# Index table: Masked residues: 24366
# Index table: fill
# [=================================================================] 33.88K 0s 425ms
# Index statistics
# Entries:          13379676
# DB size:          564 MB
# Avg k-mer size:   0.209057
# Top 10 k-mers
#     PAFDGG	925
#     NGGATM	876
#     VKQHGR	812
#     AGRKGV	740
#     IGMNGL	651
#     RSEETI	638
#     QLGDVT	636
#     EVNDGR	608
#     GGPNDV	602
#     NFDGAT	592
# Time for index table init: 0h 0m 1s 916ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 112
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 38533
# Target db start 1 to 33885
# [=================================================================] 38.53K 4s 336ms
#
# 202.419924 k-mers per position
# 2638 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 17 sequences passed prefiltering per query sequence
# 3 median result list length
# 9374 sequences with 0 size result lists
# Time for merging to pref_0: 0h 0m 0s 11ms
# Time for processing: 0h 0m 6s 846ms
# align tmp/15449720235936051922/search_tmp/1698286959523647864/q_orfs_aa tmp/15449720235936051922/target tmp/15449720235936051922/search_tmp/1698286959523647864/search/pref_0 tmp/15449720235936051922/search_tmp/1698286959523647864/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 38533 type: Aminoacid
# Target database size: 33885 type: Aminoacid
# Calculation of alignments
# [=================================================================] 38.53K 9s 969ms
# Time for merging to aln: 0h 0m 0s 10ms
# 686949 alignments calculated
# 25385 sequence pairs passed the thresholds (0.036953 of overall calculated)
# 0.658786 hits per query sequence
# Time for processing: 0h 0m 9s 991ms
# rmdb tmp/15449720235936051922/search_tmp/1698286959523647864/search/pref_0 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/15449720235936051922/search_tmp/1698286959523647864/search/aln_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/15449720235936051922/search_tmp/1698286959523647864/search/input_0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/15449720235936051922/search_tmp/1698286959523647864/search/aln_merge -v 3
#
# Time for processing: 0h 0m 0s 0ms
# offsetalignment tmp/15449720235936051922/query tmp/15449720235936051922/search_tmp/1698286959523647864/q_orfs_aa tmp/15449720235936051922/target tmp/15449720235936051922/target tmp/15449720235936051922/search_tmp/1698286959523647864/aln tmp/15449720235936051922/result --chain-alignments 0 --merge-query 1 --search-type 0 --threads 8 --compressed 0 --db-load-mode 0 -v 3
#
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 4ms
# Writing results to: tmp/15449720235936051922/result
# [=================================================================] 1 0s 0ms
#
# Time for merging to result: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 46ms
# rmdb tmp/15449720235936051922/search_tmp/1698286959523647864/q_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/15449720235936051922/search_tmp/1698286959523647864/t_orfs_aa -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/15449720235936051922/search_tmp/1698286959523647864/aln -v 3
#
# Time for processing: 0h 0m 0s 0ms
# convertalis tmp/15449720235936051922/query tmp/15449720235936051922/target tmp/15449720235936051922/result ./genomes/Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#3.tsv --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --format-mode 4 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --db-output 0 --db-load-mode 0 --search-type 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 1 0s 0ms
# Time for merging to Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#3.tsv: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 41ms
# rmdb tmp/15449720235936051922/result -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/15449720235936051922/target -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/15449720235936051922/target_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/15449720235936051922/query -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/15449720235936051922/query_h -v 3
#
# Time for processing: 0h 0m 0s 0ms

# %%
base=pathlib.Path(os.path.join(WORK_DIR))

# %%
alf=list(base.rglob("Alignment_Results_mmseq_*.tsv"))
genome_cod={}
for i in alf:
    alignment_address=i
    ecs=mg.extract_ec_from_alignment(alignment_address,save=False)
    cods=mg.get_cod_from_ec_counts(ecs,save=False)
    genome_cod.update({i.name.rstrip(".tsv"):cods})
    print(i,flush=True)
# Out:
# genomes/Alignment_Results_mmseq_GCA002344125.1~DDTQ01000011.1.tsv
# genomes/Alignment_Results_mmseq_GCA017983595.1~JAGOBC010000005.1.tsv
# genomes/Alignment_Results_mmseq_GCF001886875.1~NZCP013239.1-#11.tsv
# genomes/Alignment_Results_mmseq_GCA905211195.1~CAJLZS010000010.1.tsv
# genomes/Alignment_Results_mmseq_GCA021155145.1~JAJNPX010000541.1.tsv
# genomes/Alignment_Results_mmseq_GCA020532105.1~JAJBBI010000134.1.tsv
# genomes/Alignment_Results_mmseq_GCF002777255.1~NZCP017634.1.tsv
# genomes/Alignment_Results_mmseq_GCF009469765.1~NZSSSQ01000027.1.tsv
# genomes/Alignment_Results_mmseq_GCA928721945.1~CAKMWB010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA019136575.1~JAGVTX010000108.1.tsv
# genomes/Alignment_Results_mmseq_GCA003963305.1~RXJR01000021.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978245.1~NZNRMR01000156.1.tsv
# genomes/Alignment_Results_mmseq_GCA016703135.1~JADJCQ010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF020089545.1~NZJAIRBK010000049.1.tsv
# genomes/Alignment_Results_mmseq_GCF002995785.1~NZPVXO01000049.1.tsv
# genomes/Alignment_Results_mmseq_GCA905210905.1~CAJLYQ010000018.1.tsv
# genomes/Alignment_Results_mmseq_GCA018436565.1~JAHDLP010000118.1.tsv
# genomes/Alignment_Results_mmseq_GCA020890945.1~JAJHPK010000021.1.tsv
# genomes/Alignment_Results_mmseq_GCF900099635.1~NZFNDZ01000025.1.tsv
# genomes/Alignment_Results_mmseq_GCA022647735.1~JALCLF010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF018913775.1~NZJABAPV010000087.1.tsv
# genomes/Alignment_Results_mmseq_GCA002376755.1~DFON01000219.1.tsv
# genomes/Alignment_Results_mmseq_GCA018242735.1~JAFEBJ010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF015549795.1~NZJADMZL010000021.1.tsv
# genomes/Alignment_Results_mmseq_GCF900637655.1~NZLR134384.1.tsv
# genomes/Alignment_Results_mmseq_GCA016722305.1~JADKGK010000023.1.tsv
# genomes/Alignment_Results_mmseq_GCF003115115.2~NZBFCV01000192.1.tsv
# genomes/Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1.tsv
# genomes/Alignment_Results_mmseq_GCA018003655.1~JAGNDY010000019.1.tsv
# genomes/Alignment_Results_mmseq_GCA016702835.1~JADJDF010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF001729965.1~NZJRWK01000030.1.tsv
# genomes/Alignment_Results_mmseq_GCF019929685.1~NZJAHZPY010000049.1.tsv
# genomes/Alignment_Results_mmseq_GCA016700035.1~CP064998.1.tsv
# genomes/Alignment_Results_mmseq_GCA016708845.1~JADJFB010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA002841995.1~PHBS01000190.1.tsv
# genomes/Alignment_Results_mmseq_GCF900142105.1~NZFQZS01000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA017997995.1~JAGODX010000032.1.tsv
# genomes/Alignment_Results_mmseq_GCA019636095.1~JAHBYF010000004.1.tsv
# genomes/Alignment_Results_mmseq_GCF002954445.1~NZMQWA01000004.1.tsv
# genomes/Alignment_Results_mmseq_GCA002344715.1~DDUK01000012.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978545.1~NZNRNL01000093.1.tsv
# genomes/Alignment_Results_mmseq_GCA008125075.1~VLTH01000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA023622505.1~JAMNZC010000177.1.tsv
# genomes/Alignment_Results_mmseq_GCA019695255.1~JAIBAL010000040.1.tsv
# genomes/Alignment_Results_mmseq_GCA018268955.1~JAFDVO010000035.1.tsv
# genomes/Alignment_Results_mmseq_GCA016703545.1~JADJBX010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCF013420805.1~NZVOYH01000084.1.tsv
# genomes/Alignment_Results_mmseq_GCF002993065.1~NZNXGJ01000023.1.tsv
# genomes/Alignment_Results_mmseq_GCA016715285.1~JADKAO010000007.1.tsv
# genomes/Alignment_Results_mmseq_GCA001267515.1~CP011998.1-#6.tsv
# genomes/Alignment_Results_mmseq_GCF003570885.1~NZQXJC01000016.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978105.1~NZNRMK01000329.1.tsv
# genomes/Alignment_Results_mmseq_GCA022647645.1~JALCLC010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA016707485.1~JADJHN010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA003450035.1~DMFX01000072.1.tsv
# genomes/Alignment_Results_mmseq_GCA024234145.1~JACKOR010000008.1.tsv
# genomes/Alignment_Results_mmseq_GCA002070725.1~MWDW01000047.1.tsv
# genomes/Alignment_Results_mmseq_GCF009394175.1~NZRYCI01000227.1.tsv
# genomes/Alignment_Results_mmseq_GCA016711545.1~JADJST010000060.1.tsv
# genomes/Alignment_Results_mmseq_GCF000934545.1~NZCP010554.1.tsv
# genomes/Alignment_Results_mmseq_GCA018056985.1~JAGPEP010000012.1.tsv
# genomes/Alignment_Results_mmseq_GCA018436135.1~JAHDMH010000158.1.tsv
# genomes/Alignment_Results_mmseq_GCA022482545.1~JAKVOZ010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA002400415.1~DGQP01000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA016705885.1~JADJKQ010000004.1.tsv
# genomes/Alignment_Results_mmseq_GCF004766215.1~NZPVSH01000060.1.tsv
# genomes/Alignment_Results_mmseq_GCA015069185.1~SVJB01000013.1.tsv
# genomes/Alignment_Results_mmseq_GCA018242085.1~JAFECO010000249.1.tsv
# genomes/Alignment_Results_mmseq_GCA022652985.1~JALCRY010000050.1.tsv
# genomes/Alignment_Results_mmseq_GCA903862965.1~CAIPAB010000196.1.tsv
# genomes/Alignment_Results_mmseq_GCA903859295.1~CAIOMG010000135.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978105.1~NZNRMK01000337.1.tsv
# genomes/Alignment_Results_mmseq_GCA022484585.1~JAKVLC010000020.1.tsv
# genomes/Alignment_Results_mmseq_GCA016714465.1~JADKDT010000026.1-#2.tsv
# genomes/Alignment_Results_mmseq_GCA003674045.1~PENC01000171.1.tsv
# genomes/Alignment_Results_mmseq_GCA002069705.1~MWBV01000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA022704625.1~JAKJFZ010000046.1.tsv
# genomes/Alignment_Results_mmseq_GCA016707665.1~JADJHI010000017.1.tsv
# genomes/Alignment_Results_mmseq_GCA016714715.1~JADKCE010000011.1.tsv
# genomes/Alignment_Results_mmseq_GCA020428535.1~JAGQMS010000011.1.tsv
# genomes/Alignment_Results_mmseq_GCF001263795.1~NZLHUR01000014.1.tsv
# genomes/Alignment_Results_mmseq_GCF005222785.1~NZSTGH01000008.1.tsv
# genomes/Alignment_Results_mmseq_GCA018432185.1~JAHDLG010000164.1.tsv
# genomes/Alignment_Results_mmseq_GCA016191325.1~JACPOV010000008.1.tsv
# genomes/Alignment_Results_mmseq_GCA024397005.1~JAJDMT010000065.1.tsv
# genomes/Alignment_Results_mmseq_GCF900626095.1~NZUYZZ01000020.1.tsv
# genomes/Alignment_Results_mmseq_GCA910584465.1~CAJUBK010000010.1.tsv
# genomes/Alignment_Results_mmseq_GCA016710465.1~JADJVS010000014.1.tsv
# genomes/Alignment_Results_mmseq_GCA019694905.1~JAIBBB010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA019694255.1~JAIBCI010000092.1.tsv
# genomes/Alignment_Results_mmseq_GCA019136315.1~JAGVUL010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCF003600355.1~NZCP032416.1.tsv
# genomes/Alignment_Results_mmseq_GCA017993295.1~JAGOMZ010000076.1.tsv
# genomes/Alignment_Results_mmseq_GCA016711345.1~JADJTD010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA900316315.1~ONCK01000023.1.tsv
# genomes/Alignment_Results_mmseq_GCA017347485.1~AP021857.1.tsv
# genomes/Alignment_Results_mmseq_GCA016709925.1~JADJLW010000020.1.tsv
# genomes/Alignment_Results_mmseq_GCF020034655.1~NZJAIQDJ010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA002839185.1~PGXO01000006.1.tsv
# genomes/Alignment_Results_mmseq_GCF023806125.1~NZJAMSKT010000041.1.tsv
# genomes/Alignment_Results_mmseq_GCF002153925.1~NZMSAR01000133.1.tsv
# genomes/Alignment_Results_mmseq_GCA018433305.1~JAHDRM010000269.1.tsv
# genomes/Alignment_Results_mmseq_GCF018913685.1~NZJABAPU010000096.1.tsv
# genomes/Alignment_Results_mmseq_GCF024733635.1~NZJANRGT010000003.1-#6.tsv
# genomes/Alignment_Results_mmseq_GCF022012485.1~NZJAKLTY010000006.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978655.1~NZNRNQ01000079.1.tsv
# genomes/Alignment_Results_mmseq_GCF001913735.1~NZMSEF01000065.1.tsv
# genomes/Alignment_Results_mmseq_GCA022708305.1~JAKIYZ010000049.1.tsv
# genomes/Alignment_Results_mmseq_GCF902374565.1~NZCABKQM010000006.1.tsv
# genomes/Alignment_Results_mmseq_GCA004297485.1~SCTM01000214.1.tsv
# genomes/Alignment_Results_mmseq_GCA934149045.1~CAKPDU010000047.1.tsv
# genomes/Alignment_Results_mmseq_GCA018003215.1~JAGNEN010000098.1.tsv
# genomes/Alignment_Results_mmseq_GCA014237695.1~JAAZZJ010000126.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978035.1~NZNRMH01000215.1.tsv
# genomes/Alignment_Results_mmseq_GCA016721435.1~JADKIC010000003.1.tsv
# genomes/Alignment_Results_mmseq_GCF014287955.1~NZJACOPD010000022.1.tsv
# genomes/Alignment_Results_mmseq_GCF014642275.1~NZBMIM01000022.1.tsv
# genomes/Alignment_Results_mmseq_GCF000019545.1~NC010520.1-#2.tsv
# genomes/Alignment_Results_mmseq_GCA945865485.1~CAMBEC010000012.1.tsv
# genomes/Alignment_Results_mmseq_GCA017987975.1~JAGNSQ010000070.1.tsv
# genomes/Alignment_Results_mmseq_GCF000983115.1~NZCGIH01000026.1.tsv
# genomes/Alignment_Results_mmseq_GCA002316295.1~DCDF01000203.1.tsv
# genomes/Alignment_Results_mmseq_GCF012028635.1~NZWHXP01000031.1.tsv
# genomes/Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#3.tsv
# genomes/Alignment_Results_mmseq_GCF004127335.1~NZQFLP01000212.1.tsv
# genomes/Alignment_Results_mmseq_GCA001896575.1~MPOV01000039.1.tsv
# genomes/Alignment_Results_mmseq_GCA016715165.1~JADKBD010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA023622225.1~JAMNZQ010000026.1.tsv
# genomes/Alignment_Results_mmseq_GCA016722395.1~JADKJD010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA019694675.1~JAIBBK010000062.1.tsv
# genomes/Alignment_Results_mmseq_GCA016720145.1~JADJXV010000024.1.tsv
# genomes/Alignment_Results_mmseq_GCA016191845.1~JACPVF010000005.1.tsv
# genomes/Alignment_Results_mmseq_GCF007992495.1~NZBKAJ01000137.1.tsv
# genomes/Alignment_Results_mmseq_GCA016707525.1~JADJHP010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA022708185.1~JAKIZE010000046.1.tsv
# genomes/Alignment_Results_mmseq_GCF002976735.1~NZNRJW01000059.1.tsv
# genomes/Alignment_Results_mmseq_GCA009469585.1~SSXW01000056.1.tsv
# genomes/Alignment_Results_mmseq_GCA016712025.1~JADJRW010000008.1.tsv
# genomes/Alignment_Results_mmseq_GCA023457455.1~JAEWLR010000042.1.tsv
# genomes/Alignment_Results_mmseq_GCA019634915.1~JAHCAN010000006.1.tsv
# genomes/Alignment_Results_mmseq_GCA016716665.1~JADJVH010000014.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978715.1~NZNRNV01000131.1.tsv
# genomes/Alignment_Results_mmseq_GCA900763405.1~CAAFKE010000142.1.tsv
# genomes/Alignment_Results_mmseq_GCA003674045.1~PENC01000099.1.tsv
# genomes/Alignment_Results_mmseq_GCA001604475.1~LVBQ01000021.1.tsv
# genomes/Alignment_Results_mmseq_GCF000688255.1~NZJHYS01000032.1.tsv
# genomes/Alignment_Results_mmseq_GCA016714745.1~JADKCG010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCF014645495.1~NZBMLV01000010.1.tsv
# genomes/Alignment_Results_mmseq_GCF013664685.1~NZJAAKDE010000050.1.tsv
# genomes/Alignment_Results_mmseq_GCA016706115.1~JADJKH010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF023660965.1~NZJAHPJR010000108.1.tsv
# genomes/Alignment_Results_mmseq_GCF007556685.1~NZVJON01000110.1.tsv
# genomes/Alignment_Results_mmseq_GCF004023405.1~NZNREP01000151.1.tsv
# genomes/Alignment_Results_mmseq_GCA019454985.1~JACFNF010000068.1.tsv
# genomes/Alignment_Results_mmseq_GCA020636595.1~JACJXL010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA018436145.1~JAHDMF010000023.1.tsv
# genomes/Alignment_Results_mmseq_GCA020532445.1~JAJBAU010000126.1.tsv
# genomes/Alignment_Results_mmseq_GCF012027355.1~NZSNUH01000098.1.tsv
# genomes/Alignment_Results_mmseq_GCF001192795.1~NZDF968179.1.tsv
# genomes/Alignment_Results_mmseq_GCA009929315.1~SAAS01000150.1.tsv
# genomes/Alignment_Results_mmseq_GCF004766355.1~NZPVSO01000115.1.tsv
# genomes/Alignment_Results_mmseq_GCF900167605.1~NZFUYH01000067.1.tsv
# genomes/Alignment_Results_mmseq_GCA009877105.1~WXFD01000101.1.tsv
# genomes/Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#4.tsv
# genomes/Alignment_Results_mmseq_GCA016722195.1~JADKGP010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCF003994935.1~NZLNSX01000001.1-#4.tsv
# genomes/Alignment_Results_mmseq_GCA023415205.1~JAEZLR010000013.1.tsv
# genomes/Alignment_Results_mmseq_GCA022360315.1~JAKSDA010000145.1.tsv
# genomes/Alignment_Results_mmseq_GCF018913805.1~NZJABAPX010000095.1.tsv
# genomes/Alignment_Results_mmseq_GCA002070655.1~MWDS01000024.1.tsv
# genomes/Alignment_Results_mmseq_GCF900113135.1~NZFOOH01000056.1.tsv
# genomes/Alignment_Results_mmseq_GCA017992995.1~JAGONP010000020.1.tsv
# genomes/Alignment_Results_mmseq_GCA016700375.1~CP065016.1.tsv
# genomes/Alignment_Results_mmseq_GCA005518185.1~RKSN01000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA018436945.1~JAHDKK010000300.1.tsv
# genomes/Alignment_Results_mmseq_GCA016704085.1~JADJAV010000025.1.tsv
# genomes/Alignment_Results_mmseq_GCA017992195.1~JAGOPC010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA016709515.1~JADJMQ010000010.1.tsv
# genomes/Alignment_Results_mmseq_GCA023406645.1~JAEXVF010000013.1.tsv
# genomes/Alignment_Results_mmseq_GCF001747495.1~NZMKGI01000074.1.tsv
# genomes/Alignment_Results_mmseq_GCA024235095.1~JACKNC010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA016719685.1~JADJYP010000006.1.tsv
# genomes/Alignment_Results_mmseq_GCF020804205.1~NZWJBJ01000030.1.tsv
# genomes/Alignment_Results_mmseq_GCF009746125.1~NZCP041352.1.tsv
# genomes/Alignment_Results_mmseq_GCA022641095.1~JALCDB010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA020717815.1~DYEK01000027.1.tsv
# genomes/Alignment_Results_mmseq_GCF002001005.1~NZMUNX01000026.1.tsv
# genomes/Alignment_Results_mmseq_GCA020638195.1~JACKJC010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA017993395.1~JAGOMT010000010.1.tsv
# genomes/Alignment_Results_mmseq_GCA002256595.1~NOLC01000252.1.tsv
# genomes/Alignment_Results_mmseq_GCA022840265.1~JALHHN010000203.1.tsv
# genomes/Alignment_Results_mmseq_GCA002390845.1~DGQT01000100.1.tsv
# genomes/Alignment_Results_mmseq_GCF018141445.1~NZCP058649.1-#4.tsv
# genomes/Alignment_Results_mmseq_GCA016290425.1~JAEETS010000026.1.tsv
# genomes/Alignment_Results_mmseq_GCA928721585.1~CAKMUX010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCF900117445.1~NZFPEJ01000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA019694975.1~JAIBAY010000003.1.tsv
# genomes/Alignment_Results_mmseq_GCF001634285.1~NZCP015438.1.tsv
# genomes/Alignment_Results_mmseq_GCF000371625.1~NZKB851135.1.tsv
# genomes/Alignment_Results_mmseq_GCA017995635.1~JAGOIL010000123.1.tsv
# genomes/Alignment_Results_mmseq_GCA934882055.1~CAKXSW010000054.1.tsv
# genomes/Alignment_Results_mmseq_GCA002600545.1~JPMH01000006.1.tsv
# genomes/Alignment_Results_mmseq_GCA016721725.1~JADKHN010000006.1.tsv
# genomes/Alignment_Results_mmseq_GCA934864355.1~CAKWYU010000015.1.tsv
# genomes/Alignment_Results_mmseq_GCA016706035.1~JADJKJ010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA018055865.1~JAGPGR010000025.1.tsv
# genomes/Alignment_Results_mmseq_GCA016721345.1~JADKII010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA022840345.1~JALHIA010000059.1.tsv
# genomes/Alignment_Results_mmseq_GCA016704735.1~JADIZO010000009.1.tsv
# genomes/Alignment_Results_mmseq_GCA019694395.1~JAIBCC010000008.1.tsv
# genomes/Alignment_Results_mmseq_GCA013815775.1~JACDFN010000003.1.tsv
# genomes/Alignment_Results_mmseq_GCA022837845.1~JALHIV010000332.1.tsv
# genomes/Alignment_Results_mmseq_GCA000696115.1~JJOH01000113.1.tsv
# genomes/Alignment_Results_mmseq_GCA012797505.1~JAAZOZ010000196.1.tsv
# genomes/Alignment_Results_mmseq_GCF004766405.1~NZPVSK01000114.1.tsv
# genomes/Alignment_Results_mmseq_GCF018408575.1~NZAP023418.1-#2.tsv
# genomes/Alignment_Results_mmseq_GCA016720195.1~JADKLC010000011.1.tsv
# genomes/Alignment_Results_mmseq_GCA903878645.1~CAIRIH010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA016709425.1~JADJMR010000031.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978715.1~NZNRNV01000097.1.tsv
# genomes/Alignment_Results_mmseq_GCF001184735.1~NZLFGY01000036.1.tsv
# genomes/Alignment_Results_mmseq_GCF004766405.1~NZPVSK01000071.1.tsv
# genomes/Alignment_Results_mmseq_GCF012912135.1~NZQMEB01000425.1.tsv
# genomes/Alignment_Results_mmseq_GCF004766405.1~NZPVSK01000110.1.tsv
# genomes/Alignment_Results_mmseq_GCF001262605.1~NZLGTC01000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA023399195.1~JAEWQK010000003.1.tsv
# genomes/Alignment_Results_mmseq_GCA018000955.1~JAGNIX010000012.1.tsv
# genomes/Alignment_Results_mmseq_GCA018437055.1~JAHDKE010000373.1.tsv
# genomes/Alignment_Results_mmseq_GCA016793445.1~JAEUME010000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA020160975.1~JAIUPJ010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF023278045.1~NZCP056783.1-#3.tsv
# genomes/Alignment_Results_mmseq_GCA022839495.1~JALHEV010000241.1.tsv
# genomes/Alignment_Results_mmseq_GCA002255925.1~NKIH01000007.1.tsv
# genomes/Alignment_Results_mmseq_GCA004138365.1~RXHR01000031.1.tsv
# genomes/Alignment_Results_mmseq_GCA016722575.1~JADKIY010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCA016703965.1~JADJBB010000025.1.tsv
# genomes/Alignment_Results_mmseq_GCA021300375.1~JAJTEJ010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF002978625.1~NZNRNO01000167.1.tsv
# genomes/Alignment_Results_mmseq_GCA020073365.1~JAIQFL010000216.1.tsv
# genomes/Alignment_Results_mmseq_GCA018053065.1~JAGPMB010000038.1.tsv
# genomes/Alignment_Results_mmseq_GCA016720775.1~JADKJX010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF001050195.2~NZDF967965.1.tsv
# genomes/Alignment_Results_mmseq_GCF002193355.1~NZNHQF01000083.1.tsv
# genomes/Alignment_Results_mmseq_GCA003516025.1~CP023991.1.tsv
# genomes/Alignment_Results_mmseq_GCA022708005.1~JAKIZN010000274.1.tsv
# genomes/Alignment_Results_mmseq_GCF001902585.1~NZLKKV01000095.1.tsv
# genomes/Alignment_Results_mmseq_GCA001516055.1~LOEZ01000043.1.tsv
# genomes/Alignment_Results_mmseq_GCA016719395.1~JADJZF010000006.1.tsv
# genomes/Alignment_Results_mmseq_GCF000526395.1~NZJAFZ01000002.1.tsv
# genomes/Alignment_Results_mmseq_GCA024235995.1~JACKLI010000001.1.tsv
# genomes/Alignment_Results_mmseq_GCF900095295.1~NZLT607756.1.tsv

# %%
genome_cod
# Out:
# {'Alignment_Results_mmseq_GCA002344125.1~DDTQ01000011.1': {'X_ch': 1,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 4,
#   'X_fa': 4,
#   'X_ac_et': 2,
#   'X_ac_lac': 2,
#   'X_chain_et': 2,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA017983595.1~JAGOBC010000005.1': {'X_ch': 0,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 8,
#   'X_fa': 12,
#   'X_ac_et': 5,
#   'X_ac_lac': 5,
#   'X_chain_et': 5,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCF001886875.1~NZCP013239.1-#11': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 1,
#   'X_chain_et': 0,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA905211195.1~CAJLZS010000010.1': {'X_ch': 4,
#   'X_pr': 10,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 7,
#   'X_fa': 5,
#   'X_ac_et': 1,
#   'X_ac_lac': 3,
#   'X_chain_et': 1,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCA021155145.1~JAJNPX010000541.1': {'X_ch': 13,
#   'X_pr': 52,
#   'X_li': 2,
#   'X_su': 36,
#   'X_aa': 97,
#   'X_fa': 89,
#   'X_ac_et': 34,
#   'X_ac_lac': 49,
#   'X_chain_et': 33,
#   'X_chain_lac': 48,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 33,
#   'X_lac': 48},
#  'Alignment_Results_mmseq_GCA020532105.1~JAJBBI010000134.1': {'X_ch': 5,
#   'X_pr': 24,
#   'X_li': 0,
#   'X_su': 13,
#   'X_aa': 46,
#   'X_fa': 23,
#   'X_ac_et': 11,
#   'X_ac_lac': 17,
#   'X_chain_et': 9,
#   'X_chain_lac': 15,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 9,
#   'X_lac': 15},
#  'Alignment_Results_mmseq_GCF002777255.1~NZCP017634.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF009469765.1~NZSSSQ01000027.1': {'X_ch': 2,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 11,
#   'X_fa': 14,
#   'X_ac_et': 5,
#   'X_ac_lac': 4,
#   'X_chain_et': 5,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA928721945.1~CAKMWB010000001.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 3,
#   'X_fa': 0,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA019136575.1~JAGVTX010000108.1': {'X_ch': 4,
#   'X_pr': 9,
#   'X_li': 0,
#   'X_su': 9,
#   'X_aa': 29,
#   'X_fa': 13,
#   'X_ac_et': 9,
#   'X_ac_lac': 12,
#   'X_chain_et': 7,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 10},
#  'Alignment_Results_mmseq_GCA003963305.1~RXJR01000021.1': {'X_ch': 7,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 15,
#   'X_fa': 5,
#   'X_ac_et': 6,
#   'X_ac_lac': 6,
#   'X_chain_et': 6,
#   'X_chain_lac': 6,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 1,
#   'X_et': 6,
#   'X_lac': 6},
#  'Alignment_Results_mmseq_GCF002978245.1~NZNRMR01000156.1': {'X_ch': 14,
#   'X_pr': 7,
#   'X_li': 0,
#   'X_su': 9,
#   'X_aa': 18,
#   'X_fa': 15,
#   'X_ac_et': 10,
#   'X_ac_lac': 9,
#   'X_chain_et': 10,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCA016703135.1~JADJCQ010000001.1': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 11,
#   'X_fa': 1,
#   'X_ac_et': 1,
#   'X_ac_lac': 3,
#   'X_chain_et': 1,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF020089545.1~NZJAIRBK010000049.1': {'X_ch': 5,
#   'X_pr': 8,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 18,
#   'X_fa': 2,
#   'X_ac_et': 3,
#   'X_ac_lac': 5,
#   'X_chain_et': 3,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCF002995785.1~NZPVXO01000049.1': {'X_ch': 6,
#   'X_pr': 7,
#   'X_li': 0,
#   'X_su': 9,
#   'X_aa': 21,
#   'X_fa': 13,
#   'X_ac_et': 6,
#   'X_ac_lac': 11,
#   'X_chain_et': 6,
#   'X_chain_lac': 11,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 11},
#  'Alignment_Results_mmseq_GCA905210905.1~CAJLYQ010000018.1': {'X_ch': 11,
#   'X_pr': 9,
#   'X_li': 2,
#   'X_su': 15,
#   'X_aa': 18,
#   'X_fa': 8,
#   'X_ac_et': 8,
#   'X_ac_lac': 13,
#   'X_chain_et': 7,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCA018436565.1~JAHDLP010000118.1': {'X_ch': 11,
#   'X_pr': 28,
#   'X_li': 0,
#   'X_su': 16,
#   'X_aa': 53,
#   'X_fa': 27,
#   'X_ac_et': 13,
#   'X_ac_lac': 17,
#   'X_chain_et': 12,
#   'X_chain_lac': 16,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 12,
#   'X_lac': 16},
#  'Alignment_Results_mmseq_GCA020890945.1~JAJHPK010000021.1': {'X_ch': 3,
#   'X_pr': 12,
#   'X_li': 0,
#   'X_su': 15,
#   'X_aa': 19,
#   'X_fa': 22,
#   'X_ac_et': 10,
#   'X_ac_lac': 18,
#   'X_chain_et': 10,
#   'X_chain_lac': 18,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 18},
#  'Alignment_Results_mmseq_GCF900099635.1~NZFNDZ01000025.1': {'X_ch': 3,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 6,
#   'X_fa': 2,
#   'X_ac_et': 2,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCA022647735.1~JALCLF010000001.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCF018913775.1~NZJABAPV010000087.1': {'X_ch': 6,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 4,
#   'X_fa': 1,
#   'X_ac_et': 0,
#   'X_ac_lac': 1,
#   'X_chain_et': 0,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA002376755.1~DFON01000219.1': {'X_ch': 38,
#   'X_pr': 20,
#   'X_li': 1,
#   'X_su': 17,
#   'X_aa': 38,
#   'X_fa': 34,
#   'X_ac_et': 11,
#   'X_ac_lac': 18,
#   'X_chain_et': 10,
#   'X_chain_lac': 17,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 17},
#  'Alignment_Results_mmseq_GCA018242735.1~JAFEBJ010000001.1': {'X_ch': 0,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 8,
#   'X_fa': 8,
#   'X_ac_et': 0,
#   'X_ac_lac': 2,
#   'X_chain_et': 0,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCF015549795.1~NZJADMZL010000021.1': {'X_ch': 7,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 7,
#   'X_fa': 3,
#   'X_ac_et': 5,
#   'X_ac_lac': 5,
#   'X_chain_et': 4,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF900637655.1~NZLR134384.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA016722305.1~JADKGK010000023.1': {'X_ch': 4,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 15,
#   'X_fa': 7,
#   'X_ac_et': 6,
#   'X_ac_lac': 6,
#   'X_chain_et': 6,
#   'X_chain_lac': 6,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 6},
#  'Alignment_Results_mmseq_GCF003115115.2~NZBFCV01000192.1': {'X_ch': 22,
#   'X_pr': 8,
#   'X_li': 0,
#   'X_su': 11,
#   'X_aa': 24,
#   'X_fa': 19,
#   'X_ac_et': 7,
#   'X_ac_lac': 9,
#   'X_chain_et': 7,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA018003655.1~JAGNDY010000019.1': {'X_ch': 9,
#   'X_pr': 15,
#   'X_li': 1,
#   'X_su': 24,
#   'X_aa': 43,
#   'X_fa': 33,
#   'X_ac_et': 21,
#   'X_ac_lac': 28,
#   'X_chain_et': 20,
#   'X_chain_lac': 27,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 2,
#   'X_Me_CO2': 0,
#   'X_et': 20,
#   'X_lac': 27},
#  'Alignment_Results_mmseq_GCA016702835.1~JADJDF010000001.1': {'X_ch': 5,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 6,
#   'X_fa': 2,
#   'X_ac_et': 2,
#   'X_ac_lac': 2,
#   'X_chain_et': 2,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCF001729965.1~NZJRWK01000030.1': {'X_ch': 0,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 7,
#   'X_fa': 5,
#   'X_ac_et': 3,
#   'X_ac_lac': 4,
#   'X_chain_et': 3,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 2,
#   'X_et': 3,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF019929685.1~NZJAHZPY010000049.1': {'X_ch': 5,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 9,
#   'X_aa': 10,
#   'X_fa': 2,
#   'X_ac_et': 3,
#   'X_ac_lac': 6,
#   'X_chain_et': 3,
#   'X_chain_lac': 6,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 6},
#  'Alignment_Results_mmseq_GCA016700035.1~CP064998.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA016708845.1~JADJFB010000002.1': {'X_ch': 1,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 19,
#   'X_fa': 9,
#   'X_ac_et': 6,
#   'X_ac_lac': 10,
#   'X_chain_et': 6,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 10},
#  'Alignment_Results_mmseq_GCA002841995.1~PHBS01000190.1': {'X_ch': 24,
#   'X_pr': 29,
#   'X_li': 0,
#   'X_su': 18,
#   'X_aa': 58,
#   'X_fa': 57,
#   'X_ac_et': 14,
#   'X_ac_lac': 15,
#   'X_chain_et': 10,
#   'X_chain_lac': 11,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 2,
#   'X_et': 10,
#   'X_lac': 11},
#  'Alignment_Results_mmseq_GCF900142105.1~NZFQZS01000002.1': {'X_ch': 1,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 18,
#   'X_fa': 13,
#   'X_ac_et': 7,
#   'X_ac_lac': 9,
#   'X_chain_et': 7,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCA017997995.1~JAGODX010000032.1': {'X_ch': 62,
#   'X_pr': 34,
#   'X_li': 3,
#   'X_su': 29,
#   'X_aa': 59,
#   'X_fa': 50,
#   'X_ac_et': 14,
#   'X_ac_lac': 24,
#   'X_chain_et': 13,
#   'X_chain_lac': 23,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 2,
#   'X_Me_CO2': 0,
#   'X_et': 13,
#   'X_lac': 23},
#  'Alignment_Results_mmseq_GCA019636095.1~JAHBYF010000004.1': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 6,
#   'X_fa': 3,
#   'X_ac_et': 0,
#   'X_ac_lac': 1,
#   'X_chain_et': 0,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCF002954445.1~NZMQWA01000004.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA002344715.1~DDUK01000012.1': {'X_ch': 3,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 0,
#   'X_fa': 1,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCF002978545.1~NZNRNL01000093.1': {'X_ch': 10,
#   'X_pr': 7,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 13,
#   'X_fa': 12,
#   'X_ac_et': 6,
#   'X_ac_lac': 5,
#   'X_chain_et': 6,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCA008125075.1~VLTH01000002.1': {'X_ch': 1,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 1,
#   'X_chain_et': 0,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA023622505.1~JAMNZC010000177.1': {'X_ch': 6,
#   'X_pr': 20,
#   'X_li': 1,
#   'X_su': 14,
#   'X_aa': 43,
#   'X_fa': 43,
#   'X_ac_et': 16,
#   'X_ac_lac': 19,
#   'X_chain_et': 14,
#   'X_chain_lac': 17,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 1,
#   'X_et': 14,
#   'X_lac': 17},
#  'Alignment_Results_mmseq_GCA019695255.1~JAIBAL010000040.1': {'X_ch': 2,
#   'X_pr': 23,
#   'X_li': 0,
#   'X_su': 24,
#   'X_aa': 47,
#   'X_fa': 37,
#   'X_ac_et': 20,
#   'X_ac_lac': 27,
#   'X_chain_et': 20,
#   'X_chain_lac': 27,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 20,
#   'X_lac': 27},
#  'Alignment_Results_mmseq_GCA018268955.1~JAFDVO010000035.1': {'X_ch': 3,
#   'X_pr': 9,
#   'X_li': 0,
#   'X_su': 7,
#   'X_aa': 17,
#   'X_fa': 19,
#   'X_ac_et': 7,
#   'X_ac_lac': 9,
#   'X_chain_et': 7,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCA016703545.1~JADJBX010000002.1': {'X_ch': 1,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 9,
#   'X_fa': 3,
#   'X_ac_et': 6,
#   'X_ac_lac': 8,
#   'X_chain_et': 6,
#   'X_chain_lac': 8,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 8},
#  'Alignment_Results_mmseq_GCF013420805.1~NZVOYH01000084.1': {'X_ch': 1,
#   'X_pr': 5,
#   'X_li': 1,
#   'X_su': 11,
#   'X_aa': 19,
#   'X_fa': 14,
#   'X_ac_et': 15,
#   'X_ac_lac': 12,
#   'X_chain_et': 15,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 15,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCF002993065.1~NZNXGJ01000023.1': {'X_ch': 0,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 5,
#   'X_fa': 8,
#   'X_ac_et': 4,
#   'X_ac_lac': 5,
#   'X_chain_et': 4,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCA016715285.1~JADKAO010000007.1': {'X_ch': 0,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 5,
#   'X_fa': 5,
#   'X_ac_et': 2,
#   'X_ac_lac': 2,
#   'X_chain_et': 2,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA001267515.1~CP011998.1-#6': {'X_ch': 1,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF003570885.1~NZQXJC01000016.1': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 10,
#   'X_fa': 3,
#   'X_ac_et': 3,
#   'X_ac_lac': 3,
#   'X_chain_et': 3,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF002978105.1~NZNRMK01000329.1': {'X_ch': 22,
#   'X_pr': 17,
#   'X_li': 1,
#   'X_su': 16,
#   'X_aa': 34,
#   'X_fa': 37,
#   'X_ac_et': 17,
#   'X_ac_lac': 12,
#   'X_chain_et': 17,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 1,
#   'X_et': 17,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCA022647645.1~JALCLC010000001.1': {'X_ch': 5,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 6,
#   'X_fa': 1,
#   'X_ac_et': 2,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCA016707485.1~JADJHN010000002.1': {'X_ch': 0,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA003450035.1~DMFX01000072.1': {'X_ch': 34,
#   'X_pr': 11,
#   'X_li': 0,
#   'X_su': 12,
#   'X_aa': 27,
#   'X_fa': 17,
#   'X_ac_et': 9,
#   'X_ac_lac': 11,
#   'X_chain_et': 7,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCA024234145.1~JACKOR010000008.1': {'X_ch': 0,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 14,
#   'X_fa': 7,
#   'X_ac_et': 4,
#   'X_ac_lac': 7,
#   'X_chain_et': 4,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 1,
#   'X_et': 4,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCA002070725.1~MWDW01000047.1': {'X_ch': 8,
#   'X_pr': 29,
#   'X_li': 0,
#   'X_su': 18,
#   'X_aa': 51,
#   'X_fa': 36,
#   'X_ac_et': 14,
#   'X_ac_lac': 19,
#   'X_chain_et': 13,
#   'X_chain_lac': 18,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 13,
#   'X_lac': 19},
#  'Alignment_Results_mmseq_GCF009394175.1~NZRYCI01000227.1': {'X_ch': 19,
#   'X_pr': 13,
#   'X_li': 0,
#   'X_su': 12,
#   'X_aa': 27,
#   'X_fa': 18,
#   'X_ac_et': 11,
#   'X_ac_lac': 7,
#   'X_chain_et': 11,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 11,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCA016711545.1~JADJST010000060.1': {'X_ch': 3,
#   'X_pr': 11,
#   'X_li': 0,
#   'X_su': 7,
#   'X_aa': 17,
#   'X_fa': 10,
#   'X_ac_et': 8,
#   'X_ac_lac': 9,
#   'X_chain_et': 8,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 8,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCF000934545.1~NZCP010554.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA018056985.1~JAGPEP010000012.1': {'X_ch': 33,
#   'X_pr': 28,
#   'X_li': 0,
#   'X_su': 15,
#   'X_aa': 34,
#   'X_fa': 24,
#   'X_ac_et': 11,
#   'X_ac_lac': 13,
#   'X_chain_et': 10,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCA018436135.1~JAHDMH010000158.1': {'X_ch': 24,
#   'X_pr': 31,
#   'X_li': 1,
#   'X_su': 18,
#   'X_aa': 65,
#   'X_fa': 40,
#   'X_ac_et': 14,
#   'X_ac_lac': 18,
#   'X_chain_et': 13,
#   'X_chain_lac': 17,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 1,
#   'X_et': 13,
#   'X_lac': 17},
#  'Alignment_Results_mmseq_GCA022482545.1~JAKVOZ010000001.1': {'X_ch': 2,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 12,
#   'X_fa': 2,
#   'X_ac_et': 5,
#   'X_ac_lac': 5,
#   'X_chain_et': 5,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCA002400415.1~DGQP01000001.1': {'X_ch': 2,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 8,
#   'X_fa': 3,
#   'X_ac_et': 3,
#   'X_ac_lac': 2,
#   'X_chain_et': 3,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA016705885.1~JADJKQ010000004.1': {'X_ch': 0,
#   'X_pr': 5,
#   'X_li': 1,
#   'X_su': 3,
#   'X_aa': 17,
#   'X_fa': 12,
#   'X_ac_et': 6,
#   'X_ac_lac': 7,
#   'X_chain_et': 6,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCF004766215.1~NZPVSH01000060.1': {'X_ch': 11,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 6,
#   'X_fa': 6,
#   'X_ac_et': 3,
#   'X_ac_lac': 1,
#   'X_chain_et': 3,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA015069185.1~SVJB01000013.1': {'X_ch': 6,
#   'X_pr': 6,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 14,
#   'X_fa': 10,
#   'X_ac_et': 3,
#   'X_ac_lac': 5,
#   'X_chain_et': 3,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCA018242085.1~JAFECO010000249.1': {'X_ch': 18,
#   'X_pr': 41,
#   'X_li': 1,
#   'X_su': 43,
#   'X_aa': 134,
#   'X_fa': 106,
#   'X_ac_et': 40,
#   'X_ac_lac': 49,
#   'X_chain_et': 40,
#   'X_chain_lac': 49,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 40,
#   'X_lac': 49},
#  'Alignment_Results_mmseq_GCA022652985.1~JALCRY010000050.1': {'X_ch': 1,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 39,
#   'X_fa': 19,
#   'X_ac_et': 14,
#   'X_ac_lac': 14,
#   'X_chain_et': 13,
#   'X_chain_lac': 13,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 13,
#   'X_lac': 14},
#  'Alignment_Results_mmseq_GCA903862965.1~CAIPAB010000196.1': {'X_ch': 25,
#   'X_pr': 19,
#   'X_li': 2,
#   'X_su': 22,
#   'X_aa': 62,
#   'X_fa': 57,
#   'X_ac_et': 22,
#   'X_ac_lac': 27,
#   'X_chain_et': 19,
#   'X_chain_lac': 24,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 19,
#   'X_lac': 24},
#  'Alignment_Results_mmseq_GCA903859295.1~CAIOMG010000135.1': {'X_ch': 16,
#   'X_pr': 9,
#   'X_li': 0,
#   'X_su': 18,
#   'X_aa': 41,
#   'X_fa': 31,
#   'X_ac_et': 17,
#   'X_ac_lac': 24,
#   'X_chain_et': 15,
#   'X_chain_lac': 22,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 15,
#   'X_lac': 22},
#  'Alignment_Results_mmseq_GCF002978105.1~NZNRMK01000337.1': {'X_ch': 22,
#   'X_pr': 17,
#   'X_li': 1,
#   'X_su': 16,
#   'X_aa': 34,
#   'X_fa': 37,
#   'X_ac_et': 17,
#   'X_ac_lac': 12,
#   'X_chain_et': 17,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 1,
#   'X_et': 17,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCA022484585.1~JAKVLC010000020.1': {'X_ch': 1,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 16,
#   'X_fa': 15,
#   'X_ac_et': 10,
#   'X_ac_lac': 12,
#   'X_chain_et': 10,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCA016714465.1~JADKDT010000026.1-#2': {'X_ch': 1,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 12,
#   'X_fa': 7,
#   'X_ac_et': 8,
#   'X_ac_lac': 8,
#   'X_chain_et': 8,
#   'X_chain_lac': 8,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 8,
#   'X_lac': 8},
#  'Alignment_Results_mmseq_GCA003674045.1~PENC01000171.1': {'X_ch': 2,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 14,
#   'X_fa': 16,
#   'X_ac_et': 13,
#   'X_ac_lac': 13,
#   'X_chain_et': 13,
#   'X_chain_lac': 13,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 13,
#   'X_lac': 13},
#  'Alignment_Results_mmseq_GCA002069705.1~MWBV01000002.1': {'X_ch': 2,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 6,
#   'X_fa': 4,
#   'X_ac_et': 1,
#   'X_ac_lac': 3,
#   'X_chain_et': 0,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA022704625.1~JAKJFZ010000046.1': {'X_ch': 9,
#   'X_pr': 10,
#   'X_li': 0,
#   'X_su': 14,
#   'X_aa': 31,
#   'X_fa': 17,
#   'X_ac_et': 12,
#   'X_ac_lac': 16,
#   'X_chain_et': 10,
#   'X_chain_lac': 14,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 14},
#  'Alignment_Results_mmseq_GCA016707665.1~JADJHI010000017.1': {'X_ch': 4,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 6,
#   'X_fa': 3,
#   'X_ac_et': 4,
#   'X_ac_lac': 4,
#   'X_chain_et': 4,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA016714715.1~JADKCE010000011.1': {'X_ch': 7,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 23,
#   'X_fa': 11,
#   'X_ac_et': 6,
#   'X_ac_lac': 10,
#   'X_chain_et': 6,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 10},
#  'Alignment_Results_mmseq_GCA020428535.1~JAGQMS010000011.1': {'X_ch': 2,
#   'X_pr': 7,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 6,
#   'X_fa': 3,
#   'X_ac_et': 0,
#   'X_ac_lac': 3,
#   'X_chain_et': 0,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF001263795.1~NZLHUR01000014.1': {'X_ch': 0,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 15,
#   'X_fa': 7,
#   'X_ac_et': 9,
#   'X_ac_lac': 10,
#   'X_chain_et': 9,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 9,
#   'X_lac': 11},
#  'Alignment_Results_mmseq_GCF005222785.1~NZSTGH01000008.1': {'X_ch': 3,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA018432185.1~JAHDLG010000164.1': {'X_ch': 10,
#   'X_pr': 28,
#   'X_li': 1,
#   'X_su': 20,
#   'X_aa': 40,
#   'X_fa': 33,
#   'X_ac_et': 17,
#   'X_ac_lac': 21,
#   'X_chain_et': 15,
#   'X_chain_lac': 19,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 1,
#   'X_et': 15,
#   'X_lac': 19},
#  'Alignment_Results_mmseq_GCA016191325.1~JACPOV010000008.1': {'X_ch': 0,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA024397005.1~JAJDMT010000065.1': {'X_ch': 4,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 5,
#   'X_fa': 3,
#   'X_ac_et': 3,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCF900626095.1~NZUYZZ01000020.1': {'X_ch': 1,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 7,
#   'X_fa': 6,
#   'X_ac_et': 5,
#   'X_ac_lac': 7,
#   'X_chain_et': 5,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCA910584465.1~CAJUBK010000010.1': {'X_ch': 10,
#   'X_pr': 11,
#   'X_li': 0,
#   'X_su': 12,
#   'X_aa': 39,
#   'X_fa': 26,
#   'X_ac_et': 17,
#   'X_ac_lac': 18,
#   'X_chain_et': 17,
#   'X_chain_lac': 18,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 17,
#   'X_lac': 18},
#  'Alignment_Results_mmseq_GCA016710465.1~JADJVS010000014.1': {'X_ch': 1,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 6,
#   'X_fa': 3,
#   'X_ac_et': 1,
#   'X_ac_lac': 2,
#   'X_chain_et': 1,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA019694905.1~JAIBBB010000002.1': {'X_ch': 30,
#   'X_pr': 51,
#   'X_li': 1,
#   'X_su': 32,
#   'X_aa': 85,
#   'X_fa': 79,
#   'X_ac_et': 32,
#   'X_ac_lac': 41,
#   'X_chain_et': 31,
#   'X_chain_lac': 40,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 31,
#   'X_lac': 40},
#  'Alignment_Results_mmseq_GCA019694255.1~JAIBCI010000092.1': {'X_ch': 4,
#   'X_pr': 14,
#   'X_li': 0,
#   'X_su': 14,
#   'X_aa': 38,
#   'X_fa': 23,
#   'X_ac_et': 18,
#   'X_ac_lac': 25,
#   'X_chain_et': 17,
#   'X_chain_lac': 24,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 17,
#   'X_lac': 24},
#  'Alignment_Results_mmseq_GCA019136315.1~JAGVUL010000002.1': {'X_ch': 9,
#   'X_pr': 6,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 13,
#   'X_fa': 3,
#   'X_ac_et': 4,
#   'X_ac_lac': 5,
#   'X_chain_et': 4,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCF003600355.1~NZCP032416.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA017993295.1~JAGOMZ010000076.1': {'X_ch': 12,
#   'X_pr': 6,
#   'X_li': 0,
#   'X_su': 19,
#   'X_aa': 27,
#   'X_fa': 13,
#   'X_ac_et': 10,
#   'X_ac_lac': 14,
#   'X_chain_et': 10,
#   'X_chain_lac': 14,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 14},
#  'Alignment_Results_mmseq_GCA016711345.1~JADJTD010000001.1': {'X_ch': 2,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA900316315.1~ONCK01000023.1': {'X_ch': 5,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 7,
#   'X_aa': 7,
#   'X_fa': 3,
#   'X_ac_et': 5,
#   'X_ac_lac': 7,
#   'X_chain_et': 5,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCA017347485.1~AP021857.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA016709925.1~JADJLW010000020.1': {'X_ch': 2,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 13,
#   'X_fa': 3,
#   'X_ac_et': 2,
#   'X_ac_lac': 4,
#   'X_chain_et': 2,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF020034655.1~NZJAIQDJ010000001.1': {'X_ch': 1,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 7,
#   'X_fa': 1,
#   'X_ac_et': 1,
#   'X_ac_lac': 4,
#   'X_chain_et': 1,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA002839185.1~PGXO01000006.1': {'X_ch': 1,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 6,
#   'X_fa': 2,
#   'X_ac_et': 4,
#   'X_ac_lac': 5,
#   'X_chain_et': 3,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF023806125.1~NZJAMSKT010000041.1': {'X_ch': 9,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 11,
#   'X_fa': 5,
#   'X_ac_et': 6,
#   'X_ac_lac': 8,
#   'X_chain_et': 5,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 2,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCF002153925.1~NZMSAR01000133.1': {'X_ch': 8,
#   'X_pr': 8,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 21,
#   'X_fa': 26,
#   'X_ac_et': 13,
#   'X_ac_lac': 13,
#   'X_chain_et': 13,
#   'X_chain_lac': 13,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 13,
#   'X_lac': 13},
#  'Alignment_Results_mmseq_GCA018433305.1~JAHDRM010000269.1': {'X_ch': 21,
#   'X_pr': 20,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 50,
#   'X_fa': 32,
#   'X_ac_et': 11,
#   'X_ac_lac': 11,
#   'X_chain_et': 10,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 2,
#   'X_Me_CO2': 2,
#   'X_et': 10,
#   'X_lac': 10},
#  'Alignment_Results_mmseq_GCF018913685.1~NZJABAPU010000096.1': {'X_ch': 6,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 6,
#   'X_fa': 6,
#   'X_ac_et': 0,
#   'X_ac_lac': 3,
#   'X_chain_et': 0,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF024733635.1~NZJANRGT010000003.1-#6': {'X_ch': 2,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCF022012485.1~NZJAKLTY010000006.1': {'X_ch': 3,
#   'X_pr': 8,
#   'X_li': 0,
#   'X_su': 7,
#   'X_aa': 29,
#   'X_fa': 22,
#   'X_ac_et': 6,
#   'X_ac_lac': 7,
#   'X_chain_et': 6,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCF002978655.1~NZNRNQ01000079.1': {'X_ch': 6,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 6,
#   'X_fa': 2,
#   'X_ac_et': 3,
#   'X_ac_lac': 3,
#   'X_chain_et': 3,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF001913735.1~NZMSEF01000065.1': {'X_ch': 3,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 10,
#   'X_fa': 7,
#   'X_ac_et': 3,
#   'X_ac_lac': 2,
#   'X_chain_et': 3,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA022708305.1~JAKIYZ010000049.1': {'X_ch': 7,
#   'X_pr': 11,
#   'X_li': 0,
#   'X_su': 9,
#   'X_aa': 25,
#   'X_fa': 7,
#   'X_ac_et': 7,
#   'X_ac_lac': 12,
#   'X_chain_et': 7,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCF902374565.1~NZCABKQM010000006.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 6,
#   'X_fa': 1,
#   'X_ac_et': 5,
#   'X_ac_lac': 4,
#   'X_chain_et': 5,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA004297485.1~SCTM01000214.1': {'X_ch': 8,
#   'X_pr': 15,
#   'X_li': 2,
#   'X_su': 29,
#   'X_aa': 73,
#   'X_fa': 98,
#   'X_ac_et': 53,
#   'X_ac_lac': 53,
#   'X_chain_et': 52,
#   'X_chain_lac': 52,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 1,
#   'X_et': 52,
#   'X_lac': 54},
#  'Alignment_Results_mmseq_GCA934149045.1~CAKPDU010000047.1': {'X_ch': 4,
#   'X_pr': 5,
#   'X_li': 1,
#   'X_su': 7,
#   'X_aa': 8,
#   'X_fa': 9,
#   'X_ac_et': 3,
#   'X_ac_lac': 4,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCA018003215.1~JAGNEN010000098.1': {'X_ch': 29,
#   'X_pr': 15,
#   'X_li': 0,
#   'X_su': 12,
#   'X_aa': 30,
#   'X_fa': 25,
#   'X_ac_et': 10,
#   'X_ac_lac': 11,
#   'X_chain_et': 9,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 9,
#   'X_lac': 10},
#  'Alignment_Results_mmseq_GCA014237695.1~JAAZZJ010000126.1': {'X_ch': 47,
#   'X_pr': 25,
#   'X_li': 1,
#   'X_su': 26,
#   'X_aa': 61,
#   'X_fa': 64,
#   'X_ac_et': 12,
#   'X_ac_lac': 19,
#   'X_chain_et': 11,
#   'X_chain_lac': 18,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 7,
#   'X_Me_CO2': 0,
#   'X_et': 11,
#   'X_lac': 18},
#  'Alignment_Results_mmseq_GCF002978035.1~NZNRMH01000215.1': {'X_ch': 15,
#   'X_pr': 12,
#   'X_li': 1,
#   'X_su': 9,
#   'X_aa': 25,
#   'X_fa': 27,
#   'X_ac_et': 10,
#   'X_ac_lac': 11,
#   'X_chain_et': 10,
#   'X_chain_lac': 11,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 11},
#  'Alignment_Results_mmseq_GCA016721435.1~JADKIC010000003.1': {'X_ch': 5,
#   'X_pr': 9,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 13,
#   'X_fa': 9,
#   'X_ac_et': 7,
#   'X_ac_lac': 7,
#   'X_chain_et': 7,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCF014287955.1~NZJACOPD010000022.1': {'X_ch': 4,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 9,
#   'X_fa': 2,
#   'X_ac_et': 2,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF014642275.1~NZBMIM01000022.1': {'X_ch': 4,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 8,
#   'X_fa': 3,
#   'X_ac_et': 2,
#   'X_ac_lac': 4,
#   'X_chain_et': 2,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF000019545.1~NC010520.1-#2': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA945865485.1~CAMBEC010000012.1': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 7,
#   'X_fa': 5,
#   'X_ac_et': 4,
#   'X_ac_lac': 6,
#   'X_chain_et': 4,
#   'X_chain_lac': 6,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 6},
#  'Alignment_Results_mmseq_GCA017987975.1~JAGNSQ010000070.1': {'X_ch': 15,
#   'X_pr': 21,
#   'X_li': 0,
#   'X_su': 22,
#   'X_aa': 46,
#   'X_fa': 50,
#   'X_ac_et': 22,
#   'X_ac_lac': 28,
#   'X_chain_et': 22,
#   'X_chain_lac': 28,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 22,
#   'X_lac': 28},
#  'Alignment_Results_mmseq_GCF000983115.1~NZCGIH01000026.1': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 23,
#   'X_fa': 14,
#   'X_ac_et': 9,
#   'X_ac_lac': 11,
#   'X_chain_et': 9,
#   'X_chain_lac': 11,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 9,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCA002316295.1~DCDF01000203.1': {'X_ch': 9,
#   'X_pr': 17,
#   'X_li': 0,
#   'X_su': 28,
#   'X_aa': 62,
#   'X_fa': 105,
#   'X_ac_et': 34,
#   'X_ac_lac': 41,
#   'X_chain_et': 33,
#   'X_chain_lac': 40,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 33,
#   'X_lac': 41},
#  'Alignment_Results_mmseq_GCF012028635.1~NZWHXP01000031.1': {'X_ch': 1,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 5,
#   'X_fa': 5,
#   'X_ac_et': 1,
#   'X_ac_lac': 0,
#   'X_chain_et': 1,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#3': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF004127335.1~NZQFLP01000212.1': {'X_ch': 22,
#   'X_pr': 18,
#   'X_li': 0,
#   'X_su': 19,
#   'X_aa': 36,
#   'X_fa': 33,
#   'X_ac_et': 14,
#   'X_ac_lac': 15,
#   'X_chain_et': 14,
#   'X_chain_lac': 15,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 14,
#   'X_lac': 15},
#  'Alignment_Results_mmseq_GCA001896575.1~MPOV01000039.1': {'X_ch': 20,
#   'X_pr': 14,
#   'X_li': 0,
#   'X_su': 14,
#   'X_aa': 27,
#   'X_fa': 13,
#   'X_ac_et': 12,
#   'X_ac_lac': 15,
#   'X_chain_et': 11,
#   'X_chain_lac': 14,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 11,
#   'X_lac': 14},
#  'Alignment_Results_mmseq_GCA016715165.1~JADKBD010000001.1': {'X_ch': 5,
#   'X_pr': 6,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 7,
#   'X_fa': 6,
#   'X_ac_et': 3,
#   'X_ac_lac': 4,
#   'X_chain_et': 3,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA023622225.1~JAMNZQ010000026.1': {'X_ch': 7,
#   'X_pr': 10,
#   'X_li': 0,
#   'X_su': 12,
#   'X_aa': 19,
#   'X_fa': 22,
#   'X_ac_et': 7,
#   'X_ac_lac': 8,
#   'X_chain_et': 6,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCA016722395.1~JADKJD010000001.1': {'X_ch': 5,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 6,
#   'X_fa': 5,
#   'X_ac_et': 2,
#   'X_ac_lac': 2,
#   'X_chain_et': 2,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA019694675.1~JAIBBK010000062.1': {'X_ch': 4,
#   'X_pr': 14,
#   'X_li': 1,
#   'X_su': 12,
#   'X_aa': 35,
#   'X_fa': 18,
#   'X_ac_et': 14,
#   'X_ac_lac': 17,
#   'X_chain_et': 12,
#   'X_chain_lac': 15,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 12,
#   'X_lac': 15},
#  'Alignment_Results_mmseq_GCA016720145.1~JADJXV010000024.1': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 13,
#   'X_fa': 5,
#   'X_ac_et': 6,
#   'X_ac_lac': 7,
#   'X_chain_et': 6,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCA016191845.1~JACPVF010000005.1': {'X_ch': 2,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 8,
#   'X_fa': 4,
#   'X_ac_et': 3,
#   'X_ac_lac': 3,
#   'X_chain_et': 3,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF007992495.1~NZBKAJ01000137.1': {'X_ch': 13,
#   'X_pr': 17,
#   'X_li': 1,
#   'X_su': 34,
#   'X_aa': 83,
#   'X_fa': 105,
#   'X_ac_et': 41,
#   'X_ac_lac': 43,
#   'X_chain_et': 41,
#   'X_chain_lac': 43,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 41,
#   'X_lac': 44},
#  'Alignment_Results_mmseq_GCA016707525.1~JADJHP010000002.1': {'X_ch': 8,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 6,
#   'X_fa': 1,
#   'X_ac_et': 4,
#   'X_ac_lac': 4,
#   'X_chain_et': 3,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCA022708185.1~JAKIZE010000046.1': {'X_ch': 32,
#   'X_pr': 15,
#   'X_li': 0,
#   'X_su': 15,
#   'X_aa': 40,
#   'X_fa': 42,
#   'X_ac_et': 11,
#   'X_ac_lac': 17,
#   'X_chain_et': 10,
#   'X_chain_lac': 16,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 16},
#  'Alignment_Results_mmseq_GCF002976735.1~NZNRJW01000059.1': {'X_ch': 3,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 6,
#   'X_fa': 5,
#   'X_ac_et': 2,
#   'X_ac_lac': 1,
#   'X_chain_et': 2,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA009469585.1~SSXW01000056.1': {'X_ch': 4,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 14,
#   'X_aa': 22,
#   'X_fa': 14,
#   'X_ac_et': 5,
#   'X_ac_lac': 11,
#   'X_chain_et': 5,
#   'X_chain_lac': 11,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 11},
#  'Alignment_Results_mmseq_GCA016712025.1~JADJRW010000008.1': {'X_ch': 2,
#   'X_pr': 8,
#   'X_li': 0,
#   'X_su': 12,
#   'X_aa': 27,
#   'X_fa': 11,
#   'X_ac_et': 10,
#   'X_ac_lac': 10,
#   'X_chain_et': 10,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 11},
#  'Alignment_Results_mmseq_GCA023457455.1~JAEWLR010000042.1': {'X_ch': 1,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 14,
#   'X_aa': 41,
#   'X_fa': 14,
#   'X_ac_et': 20,
#   'X_ac_lac': 20,
#   'X_chain_et': 17,
#   'X_chain_lac': 17,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 17,
#   'X_lac': 17},
#  'Alignment_Results_mmseq_GCA019634915.1~JAHCAN010000006.1': {'X_ch': 1,
#   'X_pr': 12,
#   'X_li': 0,
#   'X_su': 7,
#   'X_aa': 24,
#   'X_fa': 10,
#   'X_ac_et': 8,
#   'X_ac_lac': 7,
#   'X_chain_et': 8,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 8,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCA016716665.1~JADJVH010000014.1': {'X_ch': 7,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 7,
#   'X_fa': 5,
#   'X_ac_et': 4,
#   'X_ac_lac': 4,
#   'X_chain_et': 4,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF002978715.1~NZNRNV01000131.1': {'X_ch': 4,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 5,
#   'X_fa': 3,
#   'X_ac_et': 6,
#   'X_ac_lac': 5,
#   'X_chain_et': 6,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCA900763405.1~CAAFKE010000142.1': {'X_ch': 11,
#   'X_pr': 14,
#   'X_li': 0,
#   'X_su': 18,
#   'X_aa': 31,
#   'X_fa': 22,
#   'X_ac_et': 11,
#   'X_ac_lac': 11,
#   'X_chain_et': 10,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 10},
#  'Alignment_Results_mmseq_GCA003674045.1~PENC01000099.1': {'X_ch': 2,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 14,
#   'X_fa': 16,
#   'X_ac_et': 13,
#   'X_ac_lac': 13,
#   'X_chain_et': 13,
#   'X_chain_lac': 13,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 13,
#   'X_lac': 13},
#  'Alignment_Results_mmseq_GCA001604475.1~LVBQ01000021.1': {'X_ch': 6,
#   'X_pr': 13,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 38,
#   'X_fa': 22,
#   'X_ac_et': 14,
#   'X_ac_lac': 17,
#   'X_chain_et': 11,
#   'X_chain_lac': 14,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 1,
#   'X_et': 11,
#   'X_lac': 14},
#  'Alignment_Results_mmseq_GCF000688255.1~NZJHYS01000032.1': {'X_ch': 1,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 12,
#   'X_fa': 6,
#   'X_ac_et': 7,
#   'X_ac_lac': 6,
#   'X_chain_et': 7,
#   'X_chain_lac': 6,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 6},
#  'Alignment_Results_mmseq_GCA016714745.1~JADKCG010000002.1': {'X_ch': 2,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 14,
#   'X_fa': 6,
#   'X_ac_et': 3,
#   'X_ac_lac': 4,
#   'X_chain_et': 3,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF014645495.1~NZBMLV01000010.1': {'X_ch': 0,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 4,
#   'X_fa': 1,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF013664685.1~NZJAAKDE010000050.1': {'X_ch': 11,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 9,
#   'X_fa': 7,
#   'X_ac_et': 5,
#   'X_ac_lac': 5,
#   'X_chain_et': 4,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA016706115.1~JADJKH010000001.1': {'X_ch': 3,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 5,
#   'X_fa': 4,
#   'X_ac_et': 2,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF023660965.1~NZJAHPJR010000108.1': {'X_ch': 11,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 17,
#   'X_fa': 10,
#   'X_ac_et': 7,
#   'X_ac_lac': 6,
#   'X_chain_et': 7,
#   'X_chain_lac': 6,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 6},
#  'Alignment_Results_mmseq_GCF007556685.1~NZVJON01000110.1': {'X_ch': 1,
#   'X_pr': 6,
#   'X_li': 0,
#   'X_su': 12,
#   'X_aa': 26,
#   'X_fa': 22,
#   'X_ac_et': 6,
#   'X_ac_lac': 9,
#   'X_chain_et': 6,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCF004023405.1~NZNREP01000151.1': {'X_ch': 3,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 24,
#   'X_fa': 10,
#   'X_ac_et': 5,
#   'X_ac_lac': 9,
#   'X_chain_et': 5,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCA019454985.1~JACFNF010000068.1': {'X_ch': 6,
#   'X_pr': 14,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 20,
#   'X_fa': 10,
#   'X_ac_et': 5,
#   'X_ac_lac': 8,
#   'X_chain_et': 4,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCA020636595.1~JACJXL010000002.1': {'X_ch': 6,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 9,
#   'X_fa': 6,
#   'X_ac_et': 3,
#   'X_ac_lac': 4,
#   'X_chain_et': 3,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA018436145.1~JAHDMF010000023.1': {'X_ch': 15,
#   'X_pr': 16,
#   'X_li': 0,
#   'X_su': 18,
#   'X_aa': 42,
#   'X_fa': 17,
#   'X_ac_et': 14,
#   'X_ac_lac': 16,
#   'X_chain_et': 12,
#   'X_chain_lac': 14,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 12,
#   'X_lac': 14},
#  'Alignment_Results_mmseq_GCA020532445.1~JAJBAU010000126.1': {'X_ch': 3,
#   'X_pr': 18,
#   'X_li': 0,
#   'X_su': 13,
#   'X_aa': 37,
#   'X_fa': 26,
#   'X_ac_et': 12,
#   'X_ac_lac': 16,
#   'X_chain_et': 9,
#   'X_chain_lac': 13,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 1,
#   'X_et': 9,
#   'X_lac': 14},
#  'Alignment_Results_mmseq_GCF012027355.1~NZSNUH01000098.1': {'X_ch': 7,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 11,
#   'X_fa': 16,
#   'X_ac_et': 9,
#   'X_ac_lac': 7,
#   'X_chain_et': 9,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 9,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCF001192795.1~NZDF968179.1': {'X_ch': 1,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 2,
#   'X_ac_lac': 1,
#   'X_chain_et': 2,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA009929315.1~SAAS01000150.1': {'X_ch': 5,
#   'X_pr': 5,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 11,
#   'X_fa': 4,
#   'X_ac_et': 3,
#   'X_ac_lac': 4,
#   'X_chain_et': 3,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF004766355.1~NZPVSO01000115.1': {'X_ch': 13,
#   'X_pr': 9,
#   'X_li': 0,
#   'X_su': 18,
#   'X_aa': 22,
#   'X_fa': 10,
#   'X_ac_et': 6,
#   'X_ac_lac': 9,
#   'X_chain_et': 6,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCF900167605.1~NZFUYH01000067.1': {'X_ch': 11,
#   'X_pr': 6,
#   'X_li': 0,
#   'X_su': 9,
#   'X_aa': 15,
#   'X_fa': 8,
#   'X_ac_et': 6,
#   'X_ac_lac': 7,
#   'X_chain_et': 5,
#   'X_chain_lac': 6,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 6},
#  'Alignment_Results_mmseq_GCA009877105.1~WXFD01000101.1': {'X_ch': 13,
#   'X_pr': 11,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 19,
#   'X_fa': 8,
#   'X_ac_et': 4,
#   'X_ac_lac': 7,
#   'X_chain_et': 4,
#   'X_chain_lac': 7,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 7},
#  'Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#4': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA016722195.1~JADKGP010000002.1': {'X_ch': 1,
#   'X_pr': 0,
#   'X_li': 0,
# ...
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 6,
#   'X_fa': 2,
#   'X_ac_et': 1,
#   'X_ac_lac': 3,
#   'X_chain_et': 1,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF001634285.1~NZCP015438.1': {'X_ch': 1,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF000371625.1~NZKB851135.1': {'X_ch': 1,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 4,
#   'X_fa': 0,
#   'X_ac_et': 4,
#   'X_ac_lac': 4,
#   'X_chain_et': 3,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCA017995635.1~JAGOIL010000123.1': {'X_ch': 12,
#   'X_pr': 20,
#   'X_li': 1,
#   'X_su': 25,
#   'X_aa': 34,
#   'X_fa': 20,
#   'X_ac_et': 13,
#   'X_ac_lac': 22,
#   'X_chain_et': 12,
#   'X_chain_lac': 21,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 2,
#   'X_Me_CO2': 0,
#   'X_et': 12,
#   'X_lac': 21},
#  'Alignment_Results_mmseq_GCA934882055.1~CAKXSW010000054.1': {'X_ch': 12,
#   'X_pr': 2,
#   'X_li': 1,
#   'X_su': 3,
#   'X_aa': 10,
#   'X_fa': 6,
#   'X_ac_et': 5,
#   'X_ac_lac': 5,
#   'X_chain_et': 4,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA002600545.1~JPMH01000006.1': {'X_ch': 16,
#   'X_pr': 19,
#   'X_li': 2,
#   'X_su': 16,
#   'X_aa': 41,
#   'X_fa': 23,
#   'X_ac_et': 9,
#   'X_ac_lac': 14,
#   'X_chain_et': 7,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCA016721725.1~JADKHN010000006.1': {'X_ch': 0,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 2,
#   'X_fa': 1,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA934864355.1~CAKWYU010000015.1': {'X_ch': 31,
#   'X_pr': 8,
#   'X_li': 0,
#   'X_su': 9,
#   'X_aa': 15,
#   'X_fa': 7,
#   'X_ac_et': 6,
#   'X_ac_lac': 9,
#   'X_chain_et': 5,
#   'X_chain_lac': 8,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 8},
#  'Alignment_Results_mmseq_GCA016706035.1~JADJKJ010000001.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 3,
#   'X_fa': 0,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA018055865.1~JAGPGR010000025.1': {'X_ch': 53,
#   'X_pr': 30,
#   'X_li': 0,
#   'X_su': 23,
#   'X_aa': 50,
#   'X_fa': 48,
#   'X_ac_et': 15,
#   'X_ac_lac': 22,
#   'X_chain_et': 13,
#   'X_chain_lac': 20,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 13,
#   'X_lac': 20},
#  'Alignment_Results_mmseq_GCA016721345.1~JADKII010000002.1': {'X_ch': 1,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 8,
#   'X_fa': 2,
#   'X_ac_et': 2,
#   'X_ac_lac': 2,
#   'X_chain_et': 2,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA022840345.1~JALHIA010000059.1': {'X_ch': 4,
#   'X_pr': 9,
#   'X_li': 0,
#   'X_su': 9,
#   'X_aa': 29,
#   'X_fa': 8,
#   'X_ac_et': 4,
#   'X_ac_lac': 9,
#   'X_chain_et': 4,
#   'X_chain_lac': 9,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 9},
#  'Alignment_Results_mmseq_GCA016704735.1~JADIZO010000009.1': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 4,
#   'X_fa': 3,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA019694395.1~JAIBCC010000008.1': {'X_ch': 8,
#   'X_pr': 13,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 22,
#   'X_fa': 18,
#   'X_ac_et': 12,
#   'X_ac_lac': 14,
#   'X_chain_et': 12,
#   'X_chain_lac': 14,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 12,
#   'X_lac': 14},
#  'Alignment_Results_mmseq_GCA013815775.1~JACDFN010000003.1': {'X_ch': 1,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA022837845.1~JALHIV010000332.1': {'X_ch': 7,
#   'X_pr': 29,
#   'X_li': 0,
#   'X_su': 20,
#   'X_aa': 56,
#   'X_fa': 28,
#   'X_ac_et': 12,
#   'X_ac_lac': 20,
#   'X_chain_et': 10,
#   'X_chain_lac': 18,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 2,
#   'X_et': 10,
#   'X_lac': 19},
#  'Alignment_Results_mmseq_GCA000696115.1~JJOH01000113.1': {'X_ch': 15,
#   'X_pr': 8,
#   'X_li': 0,
#   'X_su': 7,
#   'X_aa': 20,
#   'X_fa': 16,
#   'X_ac_et': 5,
#   'X_ac_lac': 6,
#   'X_chain_et': 5,
#   'X_chain_lac': 6,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 5,
#   'X_lac': 6},
#  'Alignment_Results_mmseq_GCA012797505.1~JAAZOZ010000196.1': {'X_ch': 10,
#   'X_pr': 16,
#   'X_li': 3,
#   'X_su': 35,
#   'X_aa': 94,
#   'X_fa': 122,
#   'X_ac_et': 44,
#   'X_ac_lac': 49,
#   'X_chain_et': 43,
#   'X_chain_lac': 48,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 43,
#   'X_lac': 51},
#  'Alignment_Results_mmseq_GCF004766405.1~NZPVSK01000114.1': {'X_ch': 10,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 7,
#   'X_fa': 6,
#   'X_ac_et': 2,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF018408575.1~NZAP023418.1-#2': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 2,
#   'X_fa': 0,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA016720195.1~JADKLC010000011.1': {'X_ch': 6,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 9,
#   'X_fa': 2,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA903878645.1~CAIRIH010000001.1': {'X_ch': 0,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 3,
#   'X_fa': 3,
#   'X_ac_et': 0,
#   'X_ac_lac': 1,
#   'X_chain_et': 0,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA016709425.1~JADJMR010000031.1': {'X_ch': 6,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 10,
#   'X_fa': 8,
#   'X_ac_et': 4,
#   'X_ac_lac': 4,
#   'X_chain_et': 4,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCF002978715.1~NZNRNV01000097.1': {'X_ch': 4,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 5,
#   'X_fa': 3,
#   'X_ac_et': 6,
#   'X_ac_lac': 5,
#   'X_chain_et': 6,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCF001184735.1~NZLFGY01000036.1': {'X_ch': 11,
#   'X_pr': 4,
#   'X_li': 2,
#   'X_su': 17,
#   'X_aa': 12,
#   'X_fa': 25,
#   'X_ac_et': 10,
#   'X_ac_lac': 11,
#   'X_chain_et': 10,
#   'X_chain_lac': 11,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 10,
#   'X_lac': 11},
#  'Alignment_Results_mmseq_GCF004766405.1~NZPVSK01000071.1': {'X_ch': 10,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 7,
#   'X_fa': 6,
#   'X_ac_et': 2,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF012912135.1~NZQMEB01000425.1': {'X_ch': 20,
#   'X_pr': 33,
#   'X_li': 5,
#   'X_su': 32,
#   'X_aa': 82,
#   'X_fa': 105,
#   'X_ac_et': 29,
#   'X_ac_lac': 37,
#   'X_chain_et': 27,
#   'X_chain_lac': 35,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 27,
#   'X_lac': 35},
#  'Alignment_Results_mmseq_GCF004766405.1~NZPVSK01000110.1': {'X_ch': 10,
#   'X_pr': 4,
#   'X_li': 0,
#   'X_su': 5,
#   'X_aa': 7,
#   'X_fa': 6,
#   'X_ac_et': 2,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF001262605.1~NZLGTC01000001.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA023399195.1~JAEWQK010000003.1': {'X_ch': 0,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 8,
#   'X_aa': 20,
#   'X_fa': 19,
#   'X_ac_et': 2,
#   'X_ac_lac': 4,
#   'X_chain_et': 2,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 3,
#   'X_et': 2,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA018000955.1~JAGNIX010000012.1': {'X_ch': 1,
#   'X_pr': 13,
#   'X_li': 0,
#   'X_su': 15,
#   'X_aa': 28,
#   'X_fa': 12,
#   'X_ac_et': 9,
#   'X_ac_lac': 13,
#   'X_chain_et': 8,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 8,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCA018437055.1~JAHDKE010000373.1': {'X_ch': 99,
#   'X_pr': 39,
#   'X_li': 2,
#   'X_su': 25,
#   'X_aa': 62,
#   'X_fa': 46,
#   'X_ac_et': 20,
#   'X_ac_lac': 30,
#   'X_chain_et': 16,
#   'X_chain_lac': 26,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 16,
#   'X_lac': 26},
#  'Alignment_Results_mmseq_GCA016793445.1~JAEUME010000002.1': {'X_ch': 0,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 10,
#   'X_fa': 4,
#   'X_ac_et': 3,
#   'X_ac_lac': 4,
#   'X_chain_et': 3,
#   'X_chain_lac': 4,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 4},
#  'Alignment_Results_mmseq_GCA020160975.1~JAIUPJ010000001.1': {'X_ch': 0,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF023278045.1~NZCP056783.1-#3': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA022839495.1~JALHEV010000241.1': {'X_ch': 18,
#   'X_pr': 19,
#   'X_li': 0,
#   'X_su': 25,
#   'X_aa': 52,
#   'X_fa': 31,
#   'X_ac_et': 13,
#   'X_ac_lac': 20,
#   'X_chain_et': 12,
#   'X_chain_lac': 19,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 12,
#   'X_lac': 19},
#  'Alignment_Results_mmseq_GCA002255925.1~NKIH01000007.1': {'X_ch': 0,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 3,
#   'X_aa': 8,
#   'X_fa': 0,
#   'X_ac_et': 2,
#   'X_ac_lac': 2,
#   'X_chain_et': 2,
#   'X_chain_lac': 2,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 2},
#  'Alignment_Results_mmseq_GCA004138365.1~RXHR01000031.1': {'X_ch': 5,
#   'X_pr': 2,
#   'X_li': 1,
#   'X_su': 4,
#   'X_aa': 9,
#   'X_fa': 3,
#   'X_ac_et': 3,
#   'X_ac_lac': 5,
#   'X_chain_et': 3,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 3,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCA016722575.1~JADKIY010000001.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 3,
#   'X_fa': 2,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA016703965.1~JADJBB010000025.1': {'X_ch': 3,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 1,
#   'X_aa': 5,
#   'X_fa': 9,
#   'X_ac_et': 0,
#   'X_ac_lac': 1,
#   'X_chain_et': 0,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 1,
#   'X_et': 0,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA021300375.1~JAJTEJ010000001.1': {'X_ch': 1,
#   'X_pr': 12,
#   'X_li': 1,
#   'X_su': 6,
#   'X_aa': 14,
#   'X_fa': 11,
#   'X_ac_et': 7,
#   'X_ac_lac': 12,
#   'X_chain_et': 7,
#   'X_chain_lac': 12,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 7,
#   'X_lac': 12},
#  'Alignment_Results_mmseq_GCF002978625.1~NZNRNO01000167.1': {'X_ch': 23,
#   'X_pr': 15,
#   'X_li': 0,
#   'X_su': 11,
#   'X_aa': 24,
#   'X_fa': 26,
#   'X_ac_et': 12,
#   'X_ac_lac': 10,
#   'X_chain_et': 12,
#   'X_chain_lac': 10,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 12,
#   'X_lac': 10},
#  'Alignment_Results_mmseq_GCA020073365.1~JAIQFL010000216.1': {'X_ch': 97,
#   'X_pr': 55,
#   'X_li': 1,
#   'X_su': 48,
#   'X_aa': 117,
#   'X_fa': 126,
#   'X_ac_et': 47,
#   'X_ac_lac': 53,
#   'X_chain_et': 42,
#   'X_chain_lac': 48,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 42,
#   'X_lac': 48},
#  'Alignment_Results_mmseq_GCA018053065.1~JAGPMB010000038.1': {'X_ch': 4,
#   'X_pr': 6,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 26,
#   'X_fa': 48,
#   'X_ac_et': 13,
#   'X_ac_lac': 16,
#   'X_chain_et': 13,
#   'X_chain_lac': 16,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 13,
#   'X_lac': 16},
#  'Alignment_Results_mmseq_GCA016720775.1~JADKJX010000001.1': {'X_ch': 0,
#   'X_pr': 3,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 7,
#   'X_fa': 2,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCF001050195.2~NZDF967965.1': {'X_ch': 20,
#   'X_pr': 2,
#   'X_li': 0,
#   'X_su': 6,
#   'X_aa': 15,
#   'X_fa': 11,
#   'X_ac_et': 4,
#   'X_ac_lac': 5,
#   'X_chain_et': 4,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 4,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCF002193355.1~NZNHQF01000083.1': {'X_ch': 12,
#   'X_pr': 7,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 14,
#   'X_fa': 11,
#   'X_ac_et': 2,
#   'X_ac_lac': 3,
#   'X_chain_et': 2,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 2,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCA003516025.1~CP023991.1': {'X_ch': 0,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA022708005.1~JAKIZN010000274.1': {'X_ch': 11,
#   'X_pr': 40,
#   'X_li': 0,
#   'X_su': 37,
#   'X_aa': 75,
#   'X_fa': 56,
#   'X_ac_et': 24,
#   'X_ac_lac': 35,
#   'X_chain_et': 20,
#   'X_chain_lac': 31,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 20,
#   'X_lac': 31},
#  'Alignment_Results_mmseq_GCF001902585.1~NZLKKV01000095.1': {'X_ch': 6,
#   'X_pr': 7,
#   'X_li': 0,
#   'X_su': 10,
#   'X_aa': 16,
#   'X_fa': 7,
#   'X_ac_et': 6,
#   'X_ac_lac': 5,
#   'X_chain_et': 6,
#   'X_chain_lac': 5,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 6,
#   'X_lac': 5},
#  'Alignment_Results_mmseq_GCA001516055.1~LOEZ01000043.1': {'X_ch': 4,
#   'X_pr': 12,
#   'X_li': 0,
#   'X_su': 11,
#   'X_aa': 24,
#   'X_fa': 20,
#   'X_ac_et': 18,
#   'X_ac_lac': 17,
#   'X_chain_et': 17,
#   'X_chain_lac': 16,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 2,
#   'X_Me_CO2': 0,
#   'X_et': 17,
#   'X_lac': 16},
#  'Alignment_Results_mmseq_GCA016719395.1~JADJZF010000006.1': {'X_ch': 2,
#   'X_pr': 1,
#   'X_li': 0,
#   'X_su': 4,
#   'X_aa': 10,
#   'X_fa': 3,
#   'X_ac_et': 1,
#   'X_ac_lac': 3,
#   'X_chain_et': 1,
#   'X_chain_lac': 3,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 3},
#  'Alignment_Results_mmseq_GCF000526395.1~NZJAFZ01000002.1': {'X_ch': 1,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 2,
#   'X_aa': 1,
#   'X_fa': 0,
#   'X_ac_et': 1,
#   'X_ac_lac': 1,
#   'X_chain_et': 1,
#   'X_chain_lac': 1,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 1,
#   'X_lac': 1},
#  'Alignment_Results_mmseq_GCA024235995.1~JACKLI010000001.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 1,
#   'X_fa': 1,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF900095295.1~NZLT607756.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 1,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0}}

# %%
normalized_cods={}
samples=pathlib.Path(os.path.join(WORK_DIR,"sra_wastewater"))
for i in samples.iterdir():
    sample_basedir=i/"seqs"/i.name
    if "SRR" in i.name:
        feature_table=pd.read_table(sample_basedir/"feature-table.tsv",delimiter="\t",skiprows=1)
        matches_table=pd.read_table(sample_basedir/"matches.blast",delimiter="\t",header=None)
        genome_map=dict(zip(matches_table[0],matches_table[1]))
        feature_table["#OTU ID"]=feature_table["#OTU ID"].apply(lambda x:genome_map.get(x,x))
        total_sum=feature_table.iloc[:,1].sum()
        feature_table[i.name]=feature_table[i.name]/total_sum
        assigned=feature_table[feature_table["#OTU ID"].str.contains("_")]
        jhkhkh=[]
        for genome_ in zip(assigned["#OTU ID"].apply(lambda x:"".join(x.split("_")[1:])),assigned[i.name]):
            if ("Alignment_Results_mmseq_"+genome_[0]) not in genome_cod.keys():
                genome_cod["Alignment_Results_mmseq_"+genome_[0]]={'X_ch':0,'X_pr':0,'X_li':0,'X_su':0,'X_aa':0,'X_fa':0,'X_ac_et':0,'X_ac_lac':0,'X_chain_et':0,'X_chain_lac':0,'X_VFA_deg':0,'X_Me_ac':0,'X_Me_CO2':0,'X_et':0,'X_lac':0,}
            jhkhkh.append({i:genome_cod["Alignment_Results_mmseq_"+genome_[0]][i]*genome_[1] for i in genome_cod["Alignment_Results_mmseq_"+genome_[0]]})
        total_sample_cod=pd.DataFrame(jhkhkh).sum()
        total_sample_cod=total_sample_cod.div(total_sample_cod.sum())
        normalized_cods[i.name]=total_sample_cod.to_dict()
    else:
        continue

# %%
normalized_cods
# Out:
# {'SRR19159482': {'X_ch': 0.0678651270207852,
#   'X_pr': 0.054067436489607386,
#   'X_li': 0.001888221709006928,
#   'X_su': 0.078259584295612,
#   'X_aa': 0.18715565819861435,
#   'X_fa': 0.132105311778291,
#   'X_ac_et': 0.07681108545034641,
#   'X_ac_lac': 0.08910115473441108,
#   'X_chain_et': 0.07133856812933026,
#   'X_chain_lac': 0.08362863741339491,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0024277136258660506,
#   'X_Me_CO2': 0.00030669745958429557,
#   'X_et': 0.07133856812933026,
#   'X_lac': 0.08370623556581985},
#  'SRR19159476': {'X_ch': 0.08264441768274827,
#   'X_pr': 0.080495560981447,
#   'X_li': 0.00219213935997678,
#   'X_su': 0.07939058016584895,
#   'X_aa': 0.1888015031812754,
#   'X_fa': 0.1443833112252302,
#   'X_ac_et': 0.06449879954273142,
#   'X_ac_lac': 0.08323509867173157,
#   'X_chain_et': 0.05808023586502938,
#   'X_chain_lac': 0.07681653499402952,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0014537881237476668,
#   'X_Me_CO2': 0.0019477196403974873,
#   'X_et': 0.05808023586502938,
#   'X_lac': 0.07798007470077678},
#  'SRR19159478': {'X_ch': 0.04711639194260632,
#   'X_pr': 0.07248029633951739,
#   'X_li': 0.0009724745498989952,
#   'X_su': 0.08279736724617309,
#   'X_aa': 0.19079066601245648,
#   'X_fa': 0.13569556242181524,
#   'X_ac_et': 0.06939047947415648,
#   'X_ac_lac': 0.088256485742197,
#   'X_chain_et': 0.0682411913697304,
#   'X_chain_lac': 0.0871071976377709,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.

#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.002062535317385571,
#   'X_Me_CO2': 0.0006922207572047466,
#   'X_et': 0.07189207006969295,
#   'X_lac': 0.08383405537766057},
#  'SRR19159481': {'X_ch': 0.07495636601934819,
#   'X_pr': 0.056863673818962776,
#   'X_li': 0.0010251552331579322,
#   'X_su': 0.0805882314774563,
#   'X_aa': 0.1859813266027783,
#   'X_fa': 0.1147946769787767,
#   'X_ac_et': 0.07994913153779774,
#   'X_ac_lac': 0.09035964781375913,
#   'X_chain_et': 0.0726757200417848,
#   'X_chain_lac': 0.08308623631774621,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0025953297041972968,
#   'X_Me_CO2': 0.0008175288568221484,
#   'X_et': 0.0726757200417848,
#   'X_lac': 0.08363125555562763},
#  'SRR19159475': {'X_ch': 0.08621704692128408,
#   'X_pr': 0.08543332311892361,
#   'X_li': 0.0019537380096758326,
#   'X_su': 0.07847452433350978,
#   'X_aa': 0.1861975466844955,
#   'X_fa': 0.14571505511138358,
#   'X_ac_et': 0.06365248720877327,
#   'X_ac_lac': 0.08276271926159105,
#   'X_chain_et': 0.056723403069894436,
#   'X_chain_lac': 0.07583363512271223,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0016398770556499615,
#   'X_Me_CO2': 0.0017865931229164931,
#   'X_et': 0.056723403069894436,
#   'X_lac': 0.07688664790929606},
#  'SRR19159474': {'X_ch': 0.09197267224992643,
#   'X_pr': 0.0651897274383018,
#   'X_li': 0.0008669164022173972,
#   'X_su': 0.07982391257665052,
#   'X_aa': 0.18700341199207846,
#   'X_fa': 0.11440910500823173,
#   'X_ac_et': 0.07469001773599612,
#   'X_ac_lac': 0.08850102996031271,
#   'X_chain_et': 0.06656963565651022,
#   'X_chain_lac': 0.08038064788082684,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.002950697112134443,
#   'X_Me_CO2': 0.0006919424494762711,
#   'X_et': 0.06656963565651022,
#   'X_lac': 0.08038064788082684},
#  'SRR19159480': {'X_ch': 0.0843843200710705,
#   'X_pr': 0.060655815724347986,
#   'X_li': 0.0023201027984009136,
#   'X_su': 0.08001776762484927,
#   'X_aa': 0.194178723269243,
#   'X_fa': 0.11435925502887238,
#   'X_ac_et': 0.07519909258201661,
#   'X_ac_lac': 0.08945285233834632,
#   'X_chain_et': 0.06665635509867376,
#   'X_chain_lac': 0.08091011485500349,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0031926200901072396,
#   'X_Me_CO2': 0.0007535376610191001,
#   'X_et': 0.06665635509867376,
#   'X_lac': 0.08126308775937559},
#  'SRR19159473': {'X_ch': 0.08855764081592912,
#   'X_pr': 0.07158244486636484,
#   'X_li': 0.002443284163380556,
#   'X_su': 0.08155335670123169,
#   'X_aa': 0.19626904727131103,
#   'X_fa': 0.12287619882186848,
#   'X_ac_et': 0.06866450026775717,
#   'X_ac_lac': 0.08670768219658245,
#   'X_chain_et': 0.06067134024633661,
#   'X_chain_lac': 0.07871452217516187,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.002208996640864612,
#   'X_Me_CO2': 0.00036512341171315914,
#   'X_et': 0.06067134024633661,
#   'X_lac': 0.07871452217516187}}

# %%
genome_cod["Alignment_Results_mmseq_"+genome_[0]]
# Out:
# {'X_ch': 0,
#  'X_pr': 0,
#  'X_li': 0,
#  'X_su': 0,
#  'X_aa': 0,
#  'X_fa': 0,
#  'X_ac_et': 0,
#  'X_ac_lac': 0,
#  'X_chain_et': 0,
#  'X_chain_lac': 0,
#  'X_VFA_deg': 0,
#  'X_Me_ac': 1,
#  'X_Me_CO2': 0,
#  'X_et': 0,
#  'X_lac': 0,
#  'Alignment_Results_mmseq_GCA023457455.1~JAEWLR010000042.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GC
000002.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA018055865.1~JAGPGR010000025.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA001896575.1~MPOV01000039.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA002376755.1~DFON01000219.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA018436145.1~JAHDMF010000023.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF007556685.1~NZVJON01000110.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF900142105.1~NZFQZS01000002.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF013664685.1~NZJAAKDE010000050.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA022840345.1~JALHIA010000059.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF012028635.1~NZWHXP01000031.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF020804205.1~NZWJBJ01000030.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF002978715.1~NZNRNV01000131.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF002978655.1~NZNRNQ01000079.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA934149045.1~CAKPDU010000047.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF000526395.1~NZJAFZ01000002.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA905210905.1~CAJLYQ010000018.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#4': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF018141445.1~NZCP058649.1-#4': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF900099635.1~NZFNDZ01000025.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF002995785.1~NZPVXO01000049.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF002777255.1~NZCP017634.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA928721585.1~CAKMUX010000002.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF002978715.1~NZNRNV01000097.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF018913775.1~NZJABAPV010000087.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF002978545.1~NZNRNL01000093.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA015069185.1~SVJB01000013.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF019929685.1~NZJAHZPY010000049.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCA016290425.1~JAEETS010000026.1': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0},
#  'Alignment_Results_mmseq_GCF006016075.1~NZCP040093.1-#3': {'X_ch': 0,
#   'X_pr': 0,
#   'X_li': 0,
#   'X_su': 0,
#   'X_aa': 0,
#   'X_fa': 0,
#   'X_ac_et': 0,
#   'X_ac_lac': 0,
#   'X_chain_et': 0,
#   'X_chain_lac': 0,
#   'X_VFA_deg': 0,
#   'X_Me_ac': 0,
#   'X_Me_CO2': 0,
#   'X_et': 0,
#   'X_lac': 0}}

# %%
import json
with open("normalized_cods.json","w") as f:
    json.dump(normalized_cods,f)

# %%
metadata=pd.read_table("/Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/wastewater_16s.csv",delimiter=",")

def format_for_report(cod_dict: dict, addresses: dict,groups:dict) -> dict:
    if set(cod_dict.keys()) != set(addresses.keys()) or set(cod_dict.keys()) != set(groups.keys()):
        raise ValueError("The keys of the two dictionaries are not the same")
    else:
        return {k: {"src": addresses[k], "group": groups[k], "data": cod_dict[k]} for k in cod_dict.keys()}


metadata=metadata[metadata["Sample_Group"]=="day 0"]
normalized_cods={k:v for k,v in normalized_cods.items() if k in metadata["Run"].to_list()}
metadata["Library Name"]=metadata["Library Name"].apply(lambda x: "-".join(x.split("-")[1:]))
metadata["src"]=metadata["Library Name"].apply(lambda x: "dsjdjs" if x=="cow" else "sndd")
addresses=dict(zip(metadata["Run"],metadata["src"]))
groups=dict(zip(metadata["Run"],metadata["Library Name"]))
with open("/Users/parsaghadermarzi/Desktop/Academics/Projects/Anaerobic_Digestion_Modeling/16s_study/full_data.json","w") as f:
    json.dump(format_for_report(normalized_cods,addresses,groups),f)

# %%
{k:v for k,v in normalized_cods.items() if k in metadata["Run"].to_list()}
# Out:
# {}

# %%
normalized_cods
# Out:
# {'SRR19159476': {'X_ch': 0.08264441768274827,
#   'X_pr': 0.080495560981447,
#   'X_li': 0.00219213935997678,
#   'X_su': 0.07939058016584895,
#   'X_aa': 0.1888015031812754,
#   'X_fa': 0.1443833112252302,
#   'X_ac_et': 0.06449879954273142,
#   'X_ac_lac': 0.08323509867173157,
#   'X_chain_et': 0.05808023586502938,
#   'X_chain_lac': 0.07681653499402952,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0014537881237476668,
#   'X_Me_CO2': 0.0019477196403974873,
#   'X_et': 0.05808023586502938,
#   'X_lac': 0.07798007470077678},
#  'SRR19159478': {'X_ch': 0.04711639194260632,
#   'X_pr': 0.07248029633951739,
#   'X_li': 0.0009724745498989952,
#   'X_su': 0.08279736724617309,
#   'X_aa': 0.19079066601245648,
#   'X_fa': 0.13569556242181524,
#   'X_ac_et': 0.06939047947415648,
#   'X_ac_lac': 0.088256485742197,
#   'X_chain_et': 0.0682411913697304,
#   'X_chain_lac': 0.0871071976377709,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0012951592869109346,
#   'X_Me_CO2': 7.072542181083603e-05,
#   'X_et': 0.0682411913697304,
#   'X_lac': 0.08754481118522546},
#  'SRR19159479': {'X_ch': 0.05831868933254903,
#   'X_pr': 0.07578200819816629,
#   'X_li': 0.00173872381012468,
#   'X_su': 0.08062890957708373,
#   'X_aa': 0.1917624944099195,
#   'X_fa': 0.14272194707376681,
#   'X_ac_et': 0.06682488991484521,
#   'X_ac_lac': 0.08530509314326751,
#   'X_chain_et': 0.0644626749625627,
#   'X_chain_lac': 0.08294287819098499,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.001475224577427023,
#   'X_Me_CO2': 0.000250509833902702,
#   'X_et': 0.0644626749625627,
#   'X_lac': 0.08332328201283724},
#  'SRR19159477': {'X_ch': 0.040940464959675765,
#   'X_pr': 0.06003690962858496,
#   'X_li': 0.0018295994892368096,
#   'X_su': 0.08263055748785826,
#   'X_aa': 0.1923842921260518,
#   'X_fa': 0.14745110744767695,
#   'X_ac_et': 0.07067145665977391,
#   'X_ac_lac': 0.0880050059874914,
#   'X_chain_et': 0.06982653745120275,
#   'X_chain_lac': 0.08716008677892023,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.001133970516766564,
#   'X_Me_CO2': 0.00034940268023619627,
#   'X_et': 0.06982653745120275,
#   'X_lac': 0.08775407133532177},
#  'SRR19159483': {'X_ch': 0.051208778196601606,
#   'X_pr': 0.07216159144283713,
#   'X_li': 0.0017426141185293365,
#   'X_su': 0.0803674685717669,
#   'X_aa': 0.1826567464624736,
#   'X_fa': 0.14379625426772707,
#   'X_ac_et': 0.06996112174616645,
#   'X_ac_lac': 0.08742081269365118,
#   'X_chain_et': 0.0683882299540171,
#   'X_chain_lac': 0.08584792090150181,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0015235539065737798,
#   'X_Me_CO2': 0.00042627933137297464,
#   'X_et': 0.0683882299540171,
#   'X_lac': 0.08611039845276387},
#  'SRR19159475': {'X_ch': 0.08621704692128408,
#   'X_pr': 0.08543332311892361,
#   'X_li': 0.0019537380096758326,
#   'X_su': 0.07847452433350978,
#   'X_aa': 0.1861975466844955,
#   'X_fa': 0.14571505511138358,
#   'X_ac_et': 0.06365248720877327,
#   'X_ac_lac': 0.08276271926159105,
#   'X_chain_et': 0.056723403069894436,
#   'X_chain_lac': 0.07583363512271223,
#   'X_VFA_deg': 0.0,
#   'X_Me_ac': 0.0016398770556499615,
#   'X_Me_CO2': 0.0017865931229164931,
#   'X_et': 0.056723403069894436,
#   'X_lac': 0.07688664790929606}}

# %%
metadata["Run"]
# Out:
# 3     SRR19159475
# 4     SRR19159476
# 5     SRR19159477
# 6     SRR19159478
# 7     SRR19159479
# 11    SRR19159483
# Name: Run, dtype: object
